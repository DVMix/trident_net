# %%
# https://github.com/gsurma/cartpole
# https://towardsdatascience.com/cartpole-introduction-to-reinforcement-learning-ed0eb5b58288

# %%
import warnings
warnings.filterwarnings('ignore')

import random
import gym
import numpy as np
from collections import deque

import torch
import torch.nn.functional as F
from DQN import DQN

ENV_NAME = "CartPole-v1"

GAMMA = 0.995
LEARNING_RATE = 0.001

MEMORY_SIZE = 100000
BATCH_SIZE =  20

EXPLORATION_MAX = 1.0
EXPLORATION_MIN = 0.01
EXPLORATION_DECAY = 0.95

# %%
class DQNSolver:
    def __init__(self, observation_space, action_space, single = True):
        self.exploration_rate = EXPLORATION_MAX
        self.action_space = action_space
        self.memory = deque(maxlen=MEMORY_SIZE)
        self.single = single
        
        self.device = 'cuda' if torch.cuda.is_available() else 'cpu' 
        self.model = DQN(observation_space, action_space).to(self.device)
        
        self.model.train()
        
        if not self.single:
            self.target_net = DQN(observation_space, action_space).to(self.device)
            self.target_net.load_state_dict(self.model.state_dict())
            self.target_net.eval()
            
        #self.optimizer  = torch.optim.RMSprop(self.policy_net.parameters())
        self.loss_fn = torch.nn.MSELoss()
        self.optimizer = torch.optim.Adam(self.model.parameters(), lr = LEARNING_RATE)
        
    def remember(self, state, action, reward, next_state, done):
        self.memory.append((state, action, reward, next_state, done))

    def act(self, state):
        if np.random.rand() < self.exploration_rate:
            return random.randrange(self.action_space)
        
        if self.single:
            self.model.eval()
            q_values = self.model(state)
        else:
            q_values = self.target_net(state)
        return torch.argmax(q_values)
    
    def predict(self, state):
        if self.single:
            self.model.eval()
            prediction = self.model(state)
        else:
            prediction = self.target_net(state)
        return prediction
    
    def fit(self, state, expected_state_action_values):
        self.model.train()
        predictions = self.model(state)
        # print(predictions, expected_state_action_values)
        # F.smooth_l1_loss - Base loss fn
        loss = self.loss_fn(predictions, expected_state_action_values)
        # Optimize the model
        self.optimizer.zero_grad()
        loss.backward()
        for param in self.model.parameters():
            param.grad.data.clamp_(-1, 1)
        self.optimizer.step()
    
    def experience_replay(self):
        if len(self.memory) < BATCH_SIZE:
            return
        
        batch = random.sample(self.memory, BATCH_SIZE)
        for state, action, reward, state_next, terminal in batch:
            q_update = reward
            if not terminal:
                action_n = self.predict(state_next)
                q_update = reward + GAMMA * torch.max(action_n)
            q_values = self.predict(state) # future_action
            q_values[action] = q_update
            
            self.fit(state, q_values) 
            
        self.exploration_rate *= EXPLORATION_DECAY
        self.exploration_rate  = max(EXPLORATION_MIN, self.exploration_rate)


def cartpole():
    pass

def t_wrap(array, device):
    return torch.tensor(array, dtype = torch.float32, device=device)

# %%
# state = env.reset()
# env.render()
# cart_position, cart_velocity, pole_angle, pole_velocity = state 
# print('cart_position = ', cart_position) 
# print('cart_velocity = ', cart_velocity) 
# print('pole_angle    = ', pole_angle) 
# print('pole_velocity = ', pole_velocity)
# run += 1
# state = t_wrap(env.reset(), dqn_solver.device)
# step = 0

# %%
single = True
env = gym.make(ENV_NAME)
#score_logger = ScoreLogger(ENV_NAME)
observation_space = env.observation_space.shape[0]
action_space = env.action_space.n
dqn_solver = DQNSolver(observation_space, action_space, single)
run = 0
max_score = 0

# %%
run += 1
state = t_wrap(env.reset(), dqn_solver.device)
step = 0
env.render()
# Out:
# True

# %%
while True:
    step += 1
    env.render()    
    #action = dqn_solver.act(state)
    if np.random.rand() < dqn_solver.exploration_rate:
        action = random.randrange(dqn_solver.action_space)
    else:
        q_values = dqn_solver.model(state) # target_net
        # print('q_values =',q_values)
        action = torch.argmax(q_values)
        
    if isinstance(action, torch.Tensor):
        action = action.item()
    # print('action  =',action)

    state_next, reward, terminal, info = env.step(action)
    # print('cart_position, cart_velocity, pole_angle, pole_velocity')
    # print('state_n = ', state_next)
    # print('reward  = ', reward)
    # print('terminal= ', terminal)
    # print('info    = ', info)
    state_next = t_wrap(state_next, dqn_solver.device)
    reward = reward if not terminal else -reward
    dqn_solver.remember(state, action, reward, state_next, terminal)
    state = state_next
    # print('state = ', state)
    if terminal:
        # score_logger.add_score(step, run)
        print("Run: " + str(run) + ", exploration: " 
              + str(dqn_solver.exploration_rate) + ", score: " + str(step))
        run += 1
        state = t_wrap(env.reset(), dqn_solver.device)
        step = 0
        env.render() 
    else:
        # dqn_solver.experience_replay()
        if len(dqn_solver.memory) < BATCH_SIZE:
            # return
            print('collect more samples!')
        else:
            batch = random.sample(dqn_solver.memory, BATCH_SIZE)
            for state, action, reward, state_next, terminal in batch:
                q_update = reward
                if not terminal:
                    with torch.no_grad():
                        action_n = dqn_solver.model(state_next)
                    q_update = reward + GAMMA * torch.max(action_n)
                with torch.no_grad():
                    q_values = dqn_solver.model(state) # future_action
                q_values[action] = q_update
                # print('q_values =', q_values)
                dqn_solver.fit(state, q_values) 

            dqn_solver.exploration_rate *= EXPLORATION_DECAY
            dqn_solver.exploration_rate  = max(EXPLORATION_MIN, dqn_solver.exploration_rate)
# Out:
# collect more samples!
# collect more samples!
# collect more samples!
# collect more samples!
# collect more samples!
# collect more samples!
# collect more samples!
# collect more samples!
# collect more samples!
# collect more samples!
# collect more samples!
# collect more samples!
# collect more samples!
# Run: 1, exploration: 1.0, score: 14
# collect more samples!
# collect more samples!
# collect more samples!
# collect more samples!
# collect more samples!
# Run: 2, exploration: 0.2919890243387723, score: 30
# Run: 3, exploration: 0.18402591023557577, score: 10
# Run: 4, exploration: 0.12208654873684793, score: 9
# Run: 5, exploration: 0.0852575903343082, score: 8
# Run: 6, exploration: 0.053733545982740265, score: 10
# Run: 7, exploration: 0.03564793225056021, score: 9
# Run: 8, exploration: 0.022467088258818428, score: 10
# Run: 9, exploration: 0.014159869113351011, score: 10
# Run: 10, exploration: 0.01, score: 9
# Run: 11, exploration: 0.01, score: 10
# Run: 12, exploration: 0.01, score: 8
# Run: 13, exploration: 0.01, score: 9
# Run: 14, exploration: 0.01, score: 9
# Run: 15, exploration: 0.01, score: 10
# Run: 16, exploration: 0.01, score: 10
# Run: 17, exploration: 0.01, score: 11
# Run: 18, exploration: 0.01, score: 10
# Run: 19, exploration: 0.01, score: 11
# Run: 20, exploration: 0.01, score: 9
# Run: 21, exploration: 0.01, score: 10
# Run: 22, exploration: 0.01, score: 9
# Run: 23, exploration: 0.01, score: 9
# Run: 24, exploration: 0.01, score: 10
# Run: 25, exploration: 0.01, score: 10
# Run: 26, exploration: 0.01, score: 8
# Run: 27, exploration: 0.01, score: 9
# Run: 28, exploration: 0.01, score: 8
# Run: 29, exploration: 0.01, score: 9
# Run: 30, exploration: 0.01, score: 9
# Run: 31, exploration: 0.01, score: 10
# Run: 32, exploration: 0.01, score: 9
# Run: 33, exploration: 0.01, score: 10
# Run: 34, exploration: 0.01, score: 9
# Run: 35, exploration: 0.01, score: 9
# Run: 36, exploration: 0.01, score: 9
# Run: 37, exploration: 0.01, score: 8
# Run: 38, exploration: 0.01, score: 10
# Run: 39, exploration: 0.01, score: 10
# Run: 40, exploration: 0.01, score: 10
# Run: 41, exploration: 0.01, score: 8
# Run: 42, exploration: 0.01, score: 9
# Run: 43, exploration: 0.01, score: 9
# Run: 44, exploration: 0.01, score: 9
# Run: 45, exploration: 0.01, score: 10
# Run: 46, exploration: 0.01, score: 9
# Run: 47, exploration: 0.01, score: 10
# Run: 48, exploration: 0.01, score: 10
# Run: 49, exploration: 0.01, score: 10
# Run: 50, exploration: 0.01, score: 11
# Run: 51, exploration: 0.01, score: 8
# Run: 52, exploration: 0.01, score: 9
# Run: 53, exploration: 0.01, score: 9
# Run: 54, exploration: 0.01, score: 9
# Run: 55, exploration: 0.01, score: 9
# Run: 56, exploration: 0.01, score: 10
# Run: 57, exploration: 0.01, score: 10
# Run: 58, exploration: 0.01, score: 9
# Run: 59, exploration: 0.01, score: 10
# Run: 60, exploration: 0.01, score: 9
# Run: 61, exploration: 0.01, score: 9
# Run: 62, exploration: 0.01, score: 9
# Run: 63, exploration: 0.01, score: 10
# Run: 64, exploration: 0.01, score: 9
# Run: 65, exploration: 0.01, score: 8
# Run: 66, exploration: 0.01, score: 10
# Run: 67, exploration: 0.01, score: 9
# Run: 68, exploration: 0.01, score: 10
# Run: 69, exploration: 0.01, score: 10
# Run: 70, exploration: 0.01, score: 10
# Run: 71, exploration: 0.01, score: 9
# Run: 72, exploration: 0.01, score: 9
# Run: 73, exploration: 0.01, score: 9
# Run: 74, exploration: 0.01, score: 8
# Run: 75, exploration: 0.01, score: 9
# Run: 76, exploration: 0.01, score: 10
# Run: 77, exploration: 0.01, score: 10
# Run: 78, exploration: 0.01, score: 10
# Run: 79, exploration: 0.01, score: 10
# Run: 80, exploration: 0.01, score: 9
# Run: 81, exploration: 0.01, score: 10
# Run: 82, exploration: 0.01, score: 10
# Run: 83, exploration: 0.01, score: 9
# Run: 84, exploration: 0.01, score: 10
# Run: 85, exploration: 0.01, score: 9
# Run: 86, exploration: 0.01, score: 10
# Run: 87, exploration: 0.01, score: 9
# Run: 88, exploration: 0.01, score: 9
# Run: 89, exploration: 0.01, score: 11
# Run: 90, exploration: 0.01, score: 10
# Run: 91, exploration: 0.01, score: 10
# Run: 92, exploration: 0.01, score: 9
# Run: 93, exploration: 0.01, score: 9
# Run: 94, exploration: 0.01, score: 9
# Run: 95, exploration: 0.01, score: 10
# Run: 96, exploration: 0.01, score: 10
# Run: 97, exploration: 0.01, score: 10
# Run: 98, exploration: 0.01, score: 10
# Run: 99, exploration: 0.01, score: 9
# Run: 100, exploration: 0.01, score: 10
# Run: 101, exploration: 0.01, score: 9
# Run: 102, exploration: 0.01, score: 9
# Run: 103, exploration: 0.01, score: 10
# Run: 104, exploration: 0.01, score: 10
# Run: 105, exploration: 0.01, score: 9
# Run: 106, exploration: 0.01, score: 9
# Run: 107, exploration: 0.01, score: 11
# Run: 108, exploration: 0.01, score: 10
# Run: 109, exploration: 0.01, score: 10
# Run: 110, exploration: 0.01, score: 10
# Run: 111, exploration: 0.01, score: 9
# Run: 112, exploration: 0.01, score: 9
# Run: 113, exploration: 0.01, score: 9
# Run: 114, exploration: 0.01, score: 9
# Run: 115, exploration: 0.01, score: 10
# Run: 116, exploration: 0.01, score: 9
# Run: 117, exploration: 0.01, score: 9
# Run: 118, exploration: 0.01, score: 8
# Run: 119, exploration: 0.01, score: 9
# Run: 120, exploration: 0.01, score: 10
# Run: 121, exploration: 0.01, score: 10
# Run: 122, exploration: 0.01, score: 8
# Run: 123, exploration: 0.01, score: 9
# Run: 124, exploration: 0.01, score: 9
# Run: 125, exploration: 0.01, score: 11
# Run: 126, exploration: 0.01, score: 10
# Run: 127, exploration: 0.01, score: 10
# Run: 128, exploration: 0.01, score: 9
# Run: 129, exploration: 0.01, score: 10
# Run: 130, exploration: 0.01, score: 8
# Run: 131, exploration: 0.01, score: 10
# Run: 132, exploration: 0.01, score: 10
# Run: 133, exploration: 0.01, score: 9
# Run: 134, exploration: 0.01, score: 9
# Run: 135, exploration: 0.01, score: 10
# Run: 136, exploration: 0.01, score: 8
# Run: 137, exploration: 0.01, score: 9
# Run: 138, exploration: 0.01, score: 10
# Run: 139, exploration: 0.01, score: 10
# Run: 140, exploration: 0.01, score: 8
# Run: 141, exploration: 0.01, score: 10
# Run: 142, exploration: 0.01, score: 8
# Run: 143, exploration: 0.01, score: 10
# Run: 144, exploration: 0.01, score: 10
# Run: 145, exploration: 0.01, score: 8
# Run: 146, exploration: 0.01, score: 10
# Run: 147, exploration: 0.01, score: 10
# Run: 148, exploration: 0.01, score: 10
# Run: 149, exploration: 0.01, score: 8
# Run: 150, exploration: 0.01, score: 9
# Run: 151, exploration: 0.01, score: 10
# Run: 152, exploration: 0.01, score: 10
# Run: 153, exploration: 0.01, score: 9
# Run: 154, exploration: 0.01, score: 8
# Run: 155, exploration: 0.01, score: 9
# Run: 156, exploration: 0.01, score: 10
# Run: 157, exploration: 0.01, score: 10
# Run: 158, exploration: 0.01, score: 9
# Run: 159, exploration: 0.01, score: 9
# Run: 160, exploration: 0.01, score: 10
# Run: 161, exploration: 0.01, score: 9
# Run: 162, exploration: 0.01, score: 9
# Run: 163, exploration: 0.01, score: 9
# Run: 164, exploration: 0.01, score: 9
# Run: 165, exploration: 0.01, score: 9
# Run: 166, exploration: 0.01, score: 9
# Run: 167, exploration: 0.01, score: 9
# Run: 168, exploration: 0.01, score: 9
# Run: 169, exploration: 0.01, score: 9
# Run: 170, exploration: 0.01, score: 9
# Run: 171, exploration: 0.01, score: 10
# Run: 172, exploration: 0.01, score: 10
# Run: 173, exploration: 0.01, score: 8
# Run: 174, exploration: 0.01, score: 12
# Run: 175, exploration: 0.01, score: 9
# Run: 176, exploration: 0.01, score: 9
# Run: 177, exploration: 0.01, score: 10
# Run: 178, exploration: 0.01, score: 10
# Run: 179, exploration: 0.01, score: 8
# Run: 180, exploration: 0.01, score: 8
# Run: 181, exploration: 0.01, score: 9
# Run: 182, exploration: 0.01, score: 9
# Run: 183, exploration: 0.01, score: 9
# Run: 184, exploration: 0.01, score: 10
# Run: 185, exploration: 0.01, score: 10
# Run: 186, exploration: 0.01, score: 8
# Run: 187, exploration: 0.01, score: 10
# Run: 188, exploration: 0.01, score: 10
# Run: 189, exploration: 0.01, score: 11
# Run: 190, exploration: 0.01, score: 10
# Run: 191, exploration: 0.01, score: 11
# Run: 192, exploration: 0.01, score: 9
# Run: 193, exploration: 0.01, score: 10
# Run: 194, exploration: 0.01, score: 9
# Run: 195, exploration: 0.01, score: 8
# Run: 196, exploration: 0.01, score: 10
# Run: 197, exploration: 0.01, score: 9
# Run: 198, exploration: 0.01, score: 11
# Run: 199, exploration: 0.01, score: 10
# Run: 200, exploration: 0.01, score: 9
# Run: 201, exploration: 0.01, score: 10
# Run: 202, exploration: 0.01, score: 9
# Run: 203, exploration: 0.01, score: 8
# Run: 204, exploration: 0.01, score: 10
# Run: 205, exploration: 0.01, score: 9
# Run: 206, exploration: 0.01, score: 10
# Run: 207, exploration: 0.01, score: 9
# Run: 208, exploration: 0.01, score: 9
# Run: 209, exploration: 0.01, score: 8
# Run: 210, exploration: 0.01, score: 9
# Run: 211, exploration: 0.01, score: 10
# Run: 212, exploration: 0.01, score: 10
# Run: 213, exploration: 0.01, score: 10
# Run: 214, exploration: 0.01, score: 9
# Run: 215, exploration: 0.01, score: 9
# Run: 216, exploration: 0.01, score: 10
# Run: 217, exploration: 0.01, score: 9
# Run: 218, exploration: 0.01, score: 10
# Run: 219, exploration: 0.01, score: 10
# Run: 220, exploration: 0.01, score: 9
# Run: 221, exploration: 0.01, score: 10
# Run: 222, exploration: 0.01, score: 8
# Run: 223, exploration: 0.01, score: 9
# Run: 224, exploration: 0.01, score: 10
# Run: 225, exploration: 0.01, score: 9
# Run: 226, exploration: 0.01, score: 11
# Run: 227, exploration: 0.01, score: 10
# Run: 228, exploration: 0.01, score: 9
# Run: 229, exploration: 0.01, score: 10
# Run: 230, exploration: 0.01, score: 10
# Run: 231, exploration: 0.01, score: 9
# Run: 232, exploration: 0.01, score: 10
# Run: 233, exploration: 0.01, score: 8
# Run: 234, exploration: 0.01, score: 10
# Run: 235, exploration: 0.01, score: 10
# Run: 236, exploration: 0.01, score: 9
# Run: 237, exploration: 0.01, score: 10
# Run: 238, exploration: 0.01, score: 8
# Run: 239, exploration: 0.01, score: 9
# Run: 240, exploration: 0.01, score: 10
# Run: 241, exploration: 0.01, score: 13
# Run: 242, exploration: 0.01, score: 10
# Run: 243, exploration: 0.01, score: 8
# Run: 244, exploration: 0.01, score: 11
# Run: 245, exploration: 0.01, score: 10
# Run: 246, exploration: 0.01, score: 9
# Run: 247, exploration: 0.01, score: 9
# Run: 248, exploration: 0.01, score: 9
# Run: 249, exploration: 0.01, score: 10
# Run: 250, exploration: 0.01, score: 8
# Run: 251, exploration: 0.01, score: 10
# Run: 252, exploration: 0.01, score: 11
# Run: 253, exploration: 0.01, score: 10
# Run: 254, exploration: 0.01, score: 9
# Run: 255, exploration: 0.01, score: 11
# Run: 256, exploration: 0.01, score: 10
# Run: 257, exploration: 0.01, score: 10
# Run: 258, exploration: 0.01, score: 9
# Run: 259, exploration: 0.01, score: 10
# Run: 260, exploration: 0.01, score: 8
# Run: 261, exploration: 0.01, score: 8
# Run: 262, exploration: 0.01, score: 10
# Run: 263, exploration: 0.01, score: 10
# Run: 264, exploration: 0.01, score: 9
# Run: 265, exploration: 0.01, score: 9
# Run: 266, exploration: 0.01, score: 11
# Run: 267, exploration: 0.01, score: 8
# Run: 268, exploration: 0.01, score: 8
# Run: 269, exploration: 0.01, score: 9
# Run: 270, exploration: 0.01, score: 11
# Run: 271, exploration: 0.01, score: 9
# Run: 272, exploration: 0.01, score: 9
# Run: 273, exploration: 0.01, score: 10
# Run: 274, exploration: 0.01, score: 10
# Run: 275, exploration: 0.01, score: 8
# Run: 276, exploration: 0.01, score: 9
# Run: 277, exploration: 0.01, score: 10
# Run: 278, exploration: 0.01, score: 10
# Run: 279, exploration: 0.01, score: 9
# Run: 280, exploration: 0.01, score: 9
# Run: 281, exploration: 0.01, score: 10
# Run: 282, exploration: 0.01, score: 8
# Run: 283, exploration: 0.01, score: 8
# Run: 284, exploration: 0.01, score: 10
# Run: 285, exploration: 0.01, score: 10
# Run: 286, exploration: 0.01, score: 10
# Run: 287, exploration: 0.01, score: 9
# Run: 288, exploration: 0.01, score: 9
# Run: 289, exploration: 0.01, score: 9
# Run: 290, exploration: 0.01, score: 10
# Run: 291, exploration: 0.01, score: 9
# Run: 292, exploration: 0.01, score: 9
# Run: 293, exploration: 0.01, score: 9
# Run: 294, exploration: 0.01, score: 10
# Run: 295, exploration: 0.01, score: 10
# Run: 296, exploration: 0.01, score: 9
# Run: 297, exploration: 0.01, score: 11
# Run: 298, exploration: 0.01, score: 10
# Run: 299, exploration: 0.01, score: 9
# Run: 300, exploration: 0.01, score: 10
# Run: 301, exploration: 0.01, score: 10
# Run: 302, exploration: 0.01, score: 9
# Run: 303, exploration: 0.01, score: 10
# Run: 304, exploration: 0.01, score: 10
# Run: 305, exploration: 0.01, score: 9
# Run: 306, exploration: 0.01, score: 10
# Run: 307, exploration: 0.01, score: 10
# Run: 308, exploration: 0.01, score: 9
# Run: 309, exploration: 0.01, score: 10
# Run: 310, exploration: 0.01, score: 9
# Run: 311, exploration: 0.01, score: 9
# Run: 312, exploration: 0.01, score: 10
# Run: 313, exploration: 0.01, score: 10
# Run: 314, exploration: 0.01, score: 10
# Run: 315, exploration: 0.01, score: 8
# Run: 316, exploration: 0.01, score: 8
# Run: 317, exploration: 0.01, score: 10
# Run: 318, exploration: 0.01, score: 8
# Run: 319, exploration: 0.01, score: 9
# Run: 320, exploration: 0.01, score: 10
# Run: 321, exploration: 0.01, score: 9
# Run: 322, exploration: 0.01, score: 9
# Run: 323, exploration: 0.01, score: 11
# Run: 324, exploration: 0.01, score: 9
# Run: 325, exploration: 0.01, score: 10
# Run: 326, exploration: 0.01, score: 10
# Run: 327, exploration: 0.01, score: 10
# Run: 328, exploration: 0.01, score: 10
# Run: 329, exploration: 0.01, score: 10
# Run: 330, exploration: 0.01, score: 10
# Run: 331, exploration: 0.01, score: 10
# Run: 332, exploration: 0.01, score: 10
# Run: 333, exploration: 0.01, score: 9
# Run: 334, exploration: 0.01, score: 8
# Run: 335, exploration: 0.01, score: 9
# Run: 336, exploration: 0.01, score: 11
# Run: 337, exploration: 0.01, score: 9
# Run: 338, exploration: 0.01, score: 10
# Run: 339, exploration: 0.01, score: 9
# Run: 340, exploration: 0.01, score: 10
# Run: 341, exploration: 0.01, score: 11
# Run: 342, exploration: 0.01, score: 10
# Run: 343, exploration: 0.01, score: 9
# Run: 344, exploration: 0.01, score: 9
# Run: 345, exploration: 0.01, score: 9
# Run: 346, exploration: 0.01, score: 10
# Run: 347, exploration: 0.01, score: 9
# Run: 348, exploration: 0.01, score: 8
# Run: 349, exploration: 0.01, score: 9
# Run: 350, exploration: 0.01, score: 10
# Run: 351, exploration: 0.01, score: 10
# Run: 352, exploration: 0.01, score: 10
# Run: 353, exploration: 0.01, score: 8
# Run: 354, exploration: 0.01, score: 9
# Run: 355, exploration: 0.01, score: 10
# Run: 356, exploration: 0.01, score: 10
# Run: 357, exploration: 0.01, score: 9
# Run: 358, exploration: 0.01, score: 10
# Run: 359, exploration: 0.01, score: 8
# Run: 360, exploration: 0.01, score: 10
# Run: 361, exploration: 0.01, score: 9
# Run: 362, exploration: 0.01, score: 9
# Run: 363, exploration: 0.01, score: 9
# Run: 364, exploration: 0.01, score: 11
# Run: 365, exploration: 0.01, score: 10
# Run: 366, exploration: 0.01, score: 9
# Run: 367, exploration: 0.01, score: 10
# Run: 368, exploration: 0.01, score: 10
# Run: 369, exploration: 0.01, score: 8
# Run: 370, exploration: 0.01, score: 10
# Run: 371, exploration: 0.01, score: 9
# Run: 372, exploration: 0.01, score: 9
# Run: 373, exploration: 0.01, score: 9
# Run: 374, exploration: 0.01, score: 10
# Run: 375, exploration: 0.01, score: 9
# Run: 376, exploration: 0.01, score: 8
# Run: 377, exploration: 0.01, score: 10
# Run: 378, exploration: 0.01, score: 9
# Run: 379, exploration: 0.01, score: 10
# Run: 380, exploration: 0.01, score: 10
# Run: 381, exploration: 0.01, score: 9
# Run: 382, exploration: 0.01, score: 9
# Run: 383, exploration: 0.01, score: 10
# Run: 384, exploration: 0.01, score: 11
# Run: 385, exploration: 0.01, score: 9
# Run: 386, exploration: 0.01, score: 9
# Run: 387, exploration: 0.01, score: 8
# Run: 388, exploration: 0.01, score: 9
# Run: 389, exploration: 0.01, score: 9
# Run: 390, exploration: 0.01, score: 9
# Run: 391, exploration: 0.01, score: 10
# Run: 392, exploration: 0.01, score: 9
# Run: 393, exploration: 0.01, score: 8
# Run: 394, exploration: 0.01, score: 9
# Run: 395, exploration: 0.01, score: 10
# Run: 396, exploration: 0.01, score: 9
# Run: 397, exploration: 0.01, score: 9
# Run: 398, exploration: 0.01, score: 9
# Run: 399, exploration: 0.01, score: 10
# Run: 400, exploration: 0.01, score: 9
# Run: 401, exploration: 0.01, score: 9
# Run: 402, exploration: 0.01, score: 10
# Run: 403, exploration: 0.01, score: 11
# Run: 404, exploration: 0.01, score: 10
# Run: 405, exploration: 0.01, score: 8
# Run: 406, exploration: 0.01, score: 9
# Run: 407, exploration: 0.01, score: 9
# Run: 408, exploration: 0.01, score: 11
# Run: 409, exploration: 0.01, score: 9
# Run: 410, exploration: 0.01, score: 9
# Run: 411, exploration: 0.01, score: 10
# Run: 412, exploration: 0.01, score: 10
# Run: 413, exploration: 0.01, score: 9
# Run: 414, exploration: 0.01, score: 10
# Run: 415, exploration: 0.01, score: 9
# Run: 416, exploration: 0.01, score: 9
# Run: 417, exploration: 0.01, score: 9
# Run: 418, exploration: 0.01, score: 9
# Run: 419, exploration: 0.01, score: 9
# Run: 420, exploration: 0.01, score: 11
# Run: 421, exploration: 0.01, score: 10
# Run: 422, exploration: 0.01, score: 10
# Run: 423, exploration: 0.01, score: 10
# Run: 424, exploration: 0.01, score: 8
# Run: 425, exploration: 0.01, score: 10
# Run: 426, exploration: 0.01, score: 9
# Run: 427, exploration: 0.01, score: 10
# Run: 428, exploration: 0.01, score: 9
# Run: 429, exploration: 0.01, score: 9
# Run: 430, exploration: 0.01, score: 8
# Run: 431, exploration: 0.01, score: 9
# Run: 432, exploration: 0.01, score: 10
# Run: 433, exploration: 0.01, score: 9
# Run: 434, exploration: 0.01, score: 10
# Run: 435, exploration: 0.01, score: 8
# Run: 436, exploration: 0.01, score: 10
# Run: 437, exploration: 0.01, score: 10
# Run: 438, exploration: 0.01, score: 10
# Run: 439, exploration: 0.01, score: 10
# Run: 440, exploration: 0.01, score: 11
# Run: 441, exploration: 0.01, score: 10
# Run: 442, exploration: 0.01, score: 10
# Run: 443, exploration: 0.01, score: 10
# Run: 444, exploration: 0.01, score: 10
# Run: 445, exploration: 0.01, score: 10
# Run: 446, exploration: 0.01, score: 10
# Run: 447, exploration: 0.01, score: 9
# Run: 448, exploration: 0.01, score: 9
# Run: 449, exploration: 0.01, score: 10
# Run: 450, exploration: 0.01, score: 9
# Run: 451, exploration: 0.01, score: 10
# Run: 452, exploration: 0.01, score: 9
# Run: 453, exploration: 0.01, score: 9
# Run: 454, exploration: 0.01, score: 10
# Run: 455, exploration: 0.01, score: 9
# Run: 456, exploration: 0.01, score: 9
# Run: 457, exploration: 0.01, score: 8
# Run: 458, exploration: 0.01, score: 9
# Run: 459, exploration: 0.01, score: 10
# Run: 460, exploration: 0.01, score: 10
# Run: 461, exploration: 0.01, score: 9
# Run: 462, exploration: 0.01, score: 10
# Run: 463, exploration: 0.01, score: 10
# Run: 464, exploration: 0.01, score: 9
# Run: 465, exploration: 0.01, score: 8
# Run: 466, exploration: 0.01, score: 9
# Run: 467, exploration: 0.01, score: 10
# Run: 468, exploration: 0.01, score: 9
# Run: 469, exploration: 0.01, score: 10
# Run: 470, exploration: 0.01, score: 9
# Run: 471, exploration: 0.01, score: 8
# Run: 472, exploration: 0.01, score: 10
# Run: 473, exploration: 0.01, score: 9
# Run: 474, exploration: 0.01, score: 10
# Run: 475, exploration: 0.01, score: 10
# Run: 476, exploration: 0.01, score: 10
# Run: 477, exploration: 0.01, score: 10
# Run: 478, exploration: 0.01, score: 9
# Run: 479, exploration: 0.01, score: 9
# Run: 480, exploration: 0.01, score: 8
# Run: 481, exploration: 0.01, score: 10
# Run: 482, exploration: 0.01, score: 10
# Run: 483, exploration: 0.01, score: 10
# Run: 484, exploration: 0.01, score: 9
# Run: 485, exploration: 0.01, score: 11
# Run: 486, exploration: 0.01, score: 10
# Run: 487, exploration: 0.01, score: 9
# Run: 488, exploration: 0.01, score: 13
# Run: 489, exploration: 0.01, score: 8
# Run: 490, exploration: 0.01, score: 11
# Run: 491, exploration: 0.01, score: 10
# Run: 492, exploration: 0.01, score: 9
# Run: 493, exploration: 0.01, score: 10
# Run: 494, exploration: 0.01, score: 10
# Run: 495, exploration: 0.01, score: 9
# Run: 496, exploration: 0.01, score: 10
# Run: 497, exploration: 0.01, score: 9
# Run: 498, exploration: 0.01, score: 12
# Run: 499, exploration: 0.01, score: 10
# Run: 500, exploration: 0.01, score: 10
# Run: 501, exploration: 0.01, score: 8
# Run: 502, exploration: 0.01, score: 10
# Run: 503, exploration: 0.01, score: 9
# Run: 504, exploration: 0.01, score: 10
# Run: 505, exploration: 0.01, score: 9
# Run: 506, exploration: 0.01, score: 10
# Run: 507, exploration: 0.01, score: 8
# Run: 508, exploration: 0.01, score: 10
# Run: 509, exploration: 0.01, score: 9
# Run: 510, exploration: 0.01, score: 10
# Run: 511, exploration: 0.01, score: 11
# Run: 512, exploration: 0.01, score: 9
# Run: 513, exploration: 0.01, score: 8
# Run: 514, exploration: 0.01, score: 11
# Run: 515, exploration: 0.01, score: 10
# Run: 516, exploration: 0.01, score: 10
# Run: 517, exploration: 0.01, score: 10
# Run: 518, exploration: 0.01, score: 9
# Run: 519, exploration: 0.01, score: 10
# Run: 520, exploration: 0.01, score: 10
# Run: 521, exploration: 0.01, score: 11
# Run: 522, exploration: 0.01, score: 10
# Run: 523, exploration: 0.01, score: 10
# Run: 524, exploration: 0.01, score: 10
# Run: 525, exploration: 0.01, score: 8
# Run: 526, exploration: 0.01, score: 10
# Run: 527, exploration: 0.01, score: 10
# Run: 528, exploration: 0.01, score: 10
# Run: 529, exploration: 0.01, score: 10
# Run: 530, exploration: 0.01, score: 10
# Run: 531, exploration: 0.01, score: 9
# Run: 532, exploration: 0.01, score: 9
# Run: 533, exploration: 0.01, score: 10
# Run: 534, exploration: 0.01, score: 10
# Run: 535, exploration: 0.01, score: 10
# Run: 536, exploration: 0.01, score: 9
# Run: 537, exploration: 0.01, score: 9
# Run: 538, exploration: 0.01, score: 11
# Run: 539, exploration: 0.01, score: 10
# Run: 540, exploration: 0.01, score: 10
# Run: 541, exploration: 0.01, score: 10
# Run: 542, exploration: 0.01, score: 13
# Run: 543, exploration: 0.01, score: 10
# Run: 544, exploration: 0.01, score: 10
# Run: 545, exploration: 0.01, score: 11
# Run: 546, exploration: 0.01, score: 10
# Run: 547, exploration: 0.01, score: 10
# Run: 548, exploration: 0.01, score: 11
# Run: 549, exploration: 0.01, score: 10
# Run: 550, exploration: 0.01, score: 10
# Run: 551, exploration: 0.01, score: 8
# Run: 552, exploration: 0.01, score: 11
# Run: 553, exploration: 0.01, score: 10
# Run: 554, exploration: 0.01, score: 10
# Run: 555, exploration: 0.01, score: 9
# Run: 556, exploration: 0.01, score: 10
# Run: 557, exploration: 0.01, score: 10
# Run: 558, exploration: 0.01, score: 10
# Run: 559, exploration: 0.01, score: 9
# Run: 560, exploration: 0.01, score: 9
# Run: 561, exploration: 0.01, score: 8
# Run: 562, exploration: 0.01, score: 9
# Run: 563, exploration: 0.01, score: 10
# Run: 564, exploration: 0.01, score: 10
# Run: 565, exploration: 0.01, score: 10
# Run: 566, exploration: 0.01, score: 9
# Run: 567, exploration: 0.01, score: 10
# Run: 568, exploration: 0.01, score: 10
# Run: 569, exploration: 0.01, score: 10
# Run: 570, exploration: 0.01, score: 9
# Run: 571, exploration: 0.01, score: 10
# Run: 572, exploration: 0.01, score: 9
# Run: 573, exploration: 0.01, score: 9
# Run: 574, exploration: 0.01, score: 10
# Run: 575, exploration: 0.01, score: 10
# Run: 576, exploration: 0.01, score: 10
# Run: 577, exploration: 0.01, score: 9
# Run: 578, exploration: 0.01, score: 8
# Run: 579, exploration: 0.01, score: 9
# Run: 580, exploration: 0.01, score: 10
# Run: 581, exploration: 0.01, score: 10
# Run: 582, exploration: 0.01, score: 8
# Run: 583, exploration: 0.01, score: 10
# Run: 584, exploration: 0.01, score: 9
# Run: 585, exploration: 0.01, score: 10
# Run: 586, exploration: 0.01, score: 9
# Run: 587, exploration: 0.01, score: 8
# Run: 588, exploration: 0.01, score: 10
# Run: 589, exploration: 0.01, score: 8
# Run: 590, exploration: 0.01, score: 8
# Run: 591, exploration: 0.01, score: 9
# Run: 592, exploration: 0.01, score: 11
# Run: 593, exploration: 0.01, score: 9
# Run: 594, exploration: 0.01, score: 10
# Run: 595, exploration: 0.01, score: 8
# Run: 596, exploration: 0.01, score: 11
# Run: 597, exploration: 0.01, score: 9
# Run: 598, exploration: 0.01, score: 9
# Run: 599, exploration: 0.01, score: 9
# Run: 600, exploration: 0.01, score: 9
# Run: 601, exploration: 0.01, score: 10
# Run: 602, exploration: 0.01, score: 9
# Run: 603, exploration: 0.01, score: 10
# Run: 604, exploration: 0.01, score: 8
# Run: 605, exploration: 0.01, score: 9
# Run: 606, exploration: 0.01, score: 9
# Run: 607, exploration: 0.01, score: 9
# Run: 608, exploration: 0.01, score: 9
# Run: 609, exploration: 0.01, score: 9
# Run: 610, exploration: 0.01, score: 8
# Run: 611, exploration: 0.01, score: 8
# Run: 612, exploration: 0.01, score: 8
# Run: 613, exploration: 0.01, score: 9
# Run: 614, exploration: 0.01, score: 10
# Run: 615, exploration: 0.01, score: 10
# Run: 616, exploration: 0.01, score: 9
# Run: 617, exploration: 0.01, score: 10
# Run: 618, exploration: 0.01, score: 10
# Run: 619, exploration: 0.01, score: 10
# Run: 620, exploration: 0.01, score: 9
# Run: 621, exploration: 0.01, score: 9
# Run: 622, exploration: 0.01, score: 8
# Run: 623, exploration: 0.01, score: 10
# Run: 624, exploration: 0.01, score: 8
# Run: 625, exploration: 0.01, score: 9
# Run: 626, exploration: 0.01, score: 9
# Run: 627, exploration: 0.01, score: 9
# Run: 628, exploration: 0.01, score: 9
# Run: 629, exploration: 0.01, score: 9
# Run: 630, exploration: 0.01, score: 9
# Run: 631, exploration: 0.01, score: 10
# Run: 632, exploration: 0.01, score: 9
# Run: 633, exploration: 0.01, score: 9
# Run: 634, exploration: 0.01, score: 9
# Run: 635, exploration: 0.01, score: 9
# Run: 636, exploration: 0.01, score: 10
# Run: 637, exploration: 0.01, score: 10
# Run: 638, exploration: 0.01, score: 10
# Run: 639, exploration: 0.01, score: 9
# Run: 640, exploration: 0.01, score: 10
# Run: 641, exploration: 0.01, score: 10
# Run: 642, exploration: 0.01, score: 9
# Run: 643, exploration: 0.01, score: 10
# Run: 644, exploration: 0.01, score: 10
# Run: 645, exploration: 0.01, score: 10
# Run: 646, exploration: 0.01, score: 9
# Run: 647, exploration: 0.01, score: 10
# Run: 648, exploration: 0.01, score: 10
# Run: 649, exploration: 0.01, score: 9
# Run: 650, exploration: 0.01, score: 10
# Run: 651, exploration: 0.01, score: 9
# Run: 652, exploration: 0.01, score: 10
# Run: 653, exploration: 0.01, score: 10
# Run: 654, exploration: 0.01, score: 10
# Run: 655, exploration: 0.01, score: 10
# Run: 656, exploration: 0.01, score: 10
# Run: 657, exploration: 0.01, score: 10
# Run: 658, exploration: 0.01, score: 10
# Run: 659, exploration: 0.01, score: 9
# Run: 660, exploration: 0.01, score: 9
# Run: 661, exploration: 0.01, score: 9
# Run: 662, exploration: 0.01, score: 8
# Run: 663, exploration: 0.01, score: 9
# Run: 664, exploration: 0.01, score: 9
# Run: 665, exploration: 0.01, score: 10
# Run: 666, exploration: 0.01, score: 9
# Run: 667, exploration: 0.01, score: 9
# Run: 668, exploration: 0.01, score: 11
# Run: 669, exploration: 0.01, score: 9
# Run: 670, exploration: 0.01, score: 8
# Run: 671, exploration: 0.01, score: 11
# Run: 672, exploration: 0.01, score: 9
# Run: 673, exploration: 0.01, score: 9
# Run: 674, exploration: 0.01, score: 10
# Run: 675, exploration: 0.01, score: 9
# Run: 676, exploration: 0.01, score: 10
# Run: 677, exploration: 0.01, score: 9
# Run: 678, exploration: 0.01, score: 9
# Run: 679, exploration: 0.01, score: 9
# Run: 680, exploration: 0.01, score: 8
# Run: 681, exploration: 0.01, score: 11
# Run: 682, exploration: 0.01, score: 10
# Run: 683, exploration: 0.01, score: 8
# Run: 684, exploration: 0.01, score: 9
# Run: 685, exploration: 0.01, score: 9
# Run: 686, exploration: 0.01, score: 9
# Run: 687, exploration: 0.01, score: 10
# Run: 688, exploration: 0.01, score: 9
# Run: 689, exploration: 0.01, score: 9
# Run: 690, exploration: 0.01, score: 10
# Run: 691, exploration: 0.01, score: 9
# Run: 692, exploration: 0.01, score: 11
# Run: 693, exploration: 0.01, score: 9
# Run: 694, exploration: 0.01, score: 10
# Run: 695, exploration: 0.01, score: 10
# Run: 696, exploration: 0.01, score: 9
# Run: 697, exploration: 0.01, score: 12
# Run: 698, exploration: 0.01, score: 10
# Run: 699, exploration: 0.01, score: 11
# Run: 700, exploration: 0.01, score: 9
# Run: 701, exploration: 0.01, score: 10
# Run: 702, exploration: 0.01, score: 10
# Run: 703, exploration: 0.01, score: 9
# Run: 704, exploration: 0.01, score: 10
# Run: 705, exploration: 0.01, score: 10
# Run: 706, exploration: 0.01, score: 10
# Run: 707, exploration: 0.01, score: 9
# Run: 708, exploration: 0.01, score: 9
# Run: 709, exploration: 0.01, score: 10
# Run: 710, exploration: 0.01, score: 9
# Run: 711, exploration: 0.01, score: 10
# Run: 712, exploration: 0.01, score: 10
# Run: 713, exploration: 0.01, score: 9
# Run: 714, exploration: 0.01, score: 9
# Run: 715, exploration: 0.01, score: 9
# Run: 716, exploration: 0.01, score: 8
# Run: 717, exploration: 0.01, score: 10
# Run: 718, exploration: 0.01, score: 8
# Run: 719, exploration: 0.01, score: 9
# Run: 720, exploration: 0.01, score: 9
# Run: 721, exploration: 0.01, score: 9
# Run: 722, exploration: 0.01, score: 9
# Run: 723, exploration: 0.01, score: 10
# Run: 724, exploration: 0.01, score: 10
# Run: 725, exploration: 0.01, score: 9
# Run: 726, exploration: 0.01, score: 8
# Run: 727, exploration: 0.01, score: 9
# Run: 728, exploration: 0.01, score: 9
# Run: 729, exploration: 0.01, score: 9
# Run: 730, exploration: 0.01, score: 10
# Run: 731, exploration: 0.01, score: 10
# Run: 732, exploration: 0.01, score: 10
# Run: 733, exploration: 0.01, score: 10
# Run: 734, exploration: 0.01, score: 12
# Run: 735, exploration: 0.01, score: 8
# Run: 736, exploration: 0.01, score: 9
# Run: 737, exploration: 0.01, score: 11
# Run: 738, exploration: 0.01, score: 9
# Run: 739, exploration: 0.01, score: 9
# Run: 740, exploration: 0.01, score: 10
# Run: 741, exploration: 0.01, score: 9
# Run: 742, exploration: 0.01, score: 11
# Run: 743, exploration: 0.01, score: 9
# Run: 744, exploration: 0.01, score: 9
# Run: 745, exploration: 0.01, score: 10
# Run: 746, exploration: 0.01, score: 9
# Run: 747, exploration: 0.01, score: 9
# Run: 748, exploration: 0.01, score: 10
# Run: 749, exploration: 0.01, score: 9
# Run: 750, exploration: 0.01, score: 8
# Run: 751, exploration: 0.01, score: 9
# Run: 752, exploration: 0.01, score: 9
# Run: 753, exploration: 0.01, score: 10
# Run: 754, exploration: 0.01, score: 9
# Run: 755, exploration: 0.01, score: 11
# Run: 756, exploration: 0.01, score: 10
# Run: 757, exploration: 0.01, score: 9
# Run: 758, exploration: 0.01, score: 11
# Run: 759, exploration: 0.01, score: 9
# Run: 760, exploration: 0.01, score: 9
# Run: 761, exploration: 0.01, score: 11
# Run: 762, exploration: 0.01, score: 9
# Run: 763, exploration: 0.01, score: 8
# Run: 764, exploration: 0.01, score: 10
# Run: 765, exploration: 0.01, score: 8
# Run: 766, exploration: 0.01, score: 10
# Run: 767, exploration: 0.01, score: 12
# Run: 768, exploration: 0.01, score: 9
# Run: 769, exploration: 0.01, score: 8
# Run: 770, exploration: 0.01, score: 9
# Run: 771, exploration: 0.01, score: 9
# Run: 772, exploration: 0.01, score: 9
# Run: 773, exploration: 0.01, score: 9
# Run: 774, exploration: 0.01, score: 10
# Run: 775, exploration: 0.01, score: 10
# Run: 776, exploration: 0.01, score: 10
# Run: 777, exploration: 0.01, score: 9
# Run: 778, exploration: 0.01, score: 10
# Run: 779, exploration: 0.01, score: 9
# Run: 780, exploration: 0.01, score: 10
# Run: 781, exploration: 0.01, score: 10
# Run: 782, exploration: 0.01, score: 9
# Run: 783, exploration: 0.01, score: 8
# Run: 784, exploration: 0.01, score: 11
# Run: 785, exploration: 0.01, score: 10
# Run: 786, exploration: 0.01, score: 8
# Run: 787, exploration: 0.01, score: 9
# Run: 788, exploration: 0.01, score: 9
# Run: 789, exploration: 0.01, score: 9
# Run: 790, exploration: 0.01, score: 10
# Run: 791, exploration: 0.01, score: 9
# Run: 792, exploration: 0.01, score: 10
# Run: 793, exploration: 0.01, score: 9
# Run: 794, exploration: 0.01, score: 11
# Run: 795, exploration: 0.01, score: 10
# Run: 796, exploration: 0.01, score: 9
# Run: 797, exploration: 0.01, score: 9
# Run: 798, exploration: 0.01, score: 10
# Run: 799, exploration: 0.01, score: 11
# Run: 800, exploration: 0.01, score: 11
# Run: 801, exploration: 0.01, score: 10
# Run: 802, exploration: 0.01, score: 10
# Run: 803, exploration: 0.01, score: 8
# Run: 804, exploration: 0.01, score: 10
# Run: 805, exploration: 0.01, score: 8
# Run: 806, exploration: 0.01, score: 9
# Run: 807, exploration: 0.01, score: 11
# Run: 808, exploration: 0.01, score: 9
# Run: 809, exploration: 0.01, score: 10
# Run: 810, exploration: 0.01, score: 10
# Run: 811, exploration: 0.01, score: 10
# Run: 812, exploration: 0.01, score: 8
# Run: 813, exploration: 0.01, score: 10
# Run: 814, exploration: 0.01, score: 9
# Run: 815, exploration: 0.01, score: 8
# Run: 816, exploration: 0.01, score: 9
# Run: 817, exploration: 0.01, score: 10
# Run: 818, exploration: 0.01, score: 9
# Run: 819, exploration: 0.01, score: 10
# Run: 820, exploration: 0.01, score: 8
# Run: 821, exploration: 0.01, score: 10
# Run: 822, exploration: 0.01, score: 9
# Run: 823, exploration: 0.01, score: 10
# Run: 824, exploration: 0.01, score: 9
# Run: 825, exploration: 0.01, score: 8
# Run: 826, exploration: 0.01, score: 10
# Run: 827, exploration: 0.01, score: 8
# Run: 828, exploration: 0.01, score: 8
# Run: 829, exploration: 0.01, score: 10
# Run: 830, exploration: 0.01, score: 10
# Run: 831, exploration: 0.01, score: 10
# Run: 832, exploration: 0.01, score: 8
# Run: 833, exploration: 0.01, score: 9
# Run: 834, exploration: 0.01, score: 8
# Run: 835, exploration: 0.01, score: 9
# Run: 836, exploration: 0.01, score: 10
# Run: 837, exploration: 0.01, score: 9
# Run: 838, exploration: 0.01, score: 8
# Run: 839, exploration: 0.01, score: 10
# Run: 840, exploration: 0.01, score: 10
# Run: 841, exploration: 0.01, score: 9
# Run: 842, exploration: 0.01, score: 8
# Run: 843, exploration: 0.01, score: 10
# Run: 844, exploration: 0.01, score: 10
# Run: 845, exploration: 0.01, score: 10
# Run: 846, exploration: 0.01, score: 8
# Run: 847, exploration: 0.01, score: 8
# Run: 848, exploration: 0.01, score: 10
# Run: 849, exploration: 0.01, score: 10
# Run: 850, exploration: 0.01, score: 9
# Run: 851, exploration: 0.01, score: 10
# Run: 852, exploration: 0.01, score: 9
# Run: 853, exploration: 0.01, score: 9
# Run: 854, exploration: 0.01, score: 9
# Run: 855, exploration: 0.01, score: 9
# Run: 856, exploration: 0.01, score: 9
# Run: 857, exploration: 0.01, score: 8
# Run: 858, exploration: 0.01, score: 10
# Run: 859, exploration: 0.01, score: 9
# Run: 860, exploration: 0.01, score: 10
# Run: 861, exploration: 0.01, score: 11
# Run: 862, exploration: 0.01, score: 10
# Run: 863, exploration: 0.01, score: 9
# Run: 864, exploration: 0.01, score: 10
# Run: 865, exploration: 0.01, score: 10
# Run: 866, exploration: 0.01, score: 13
# Run: 867, exploration: 0.01, score: 10
# Run: 868, exploration: 0.01, score: 9
# Run: 869, exploration: 0.01, score: 10
# Run: 870, exploration: 0.01, score: 10
# Run: 871, exploration: 0.01, score: 10
# Run: 872, exploration: 0.01, score: 8
# Run: 873, exploration: 0.01, score: 9
# Run: 874, exploration: 0.01, score: 10
# Run: 875, exploration: 0.01, score: 8
# Run: 876, exploration: 0.01, score: 9
# Run: 877, exploration: 0.01, score: 10
# Run: 878, exploration: 0.01, score: 9
# Run: 879, exploration: 0.01, score: 10
# Run: 880, exploration: 0.01, score: 8
# Run: 881, exploration: 0.01, score: 10
# Run: 882, exploration: 0.01, score: 10
# Run: 883, exploration: 0.01, score: 10
# Run: 884, exploration: 0.01, score: 9
# Run: 885, exploration: 0.01, score: 11
# Run: 886, exploration: 0.01, score: 9
# Run: 887, exploration: 0.01, score: 10
# Run: 888, exploration: 0.01, score: 9
# Run: 889, exploration: 0.01, score: 10
# Run: 890, exploration: 0.01, score: 10
# Run: 891, exploration: 0.01, score: 10
# Run: 892, exploration: 0.01, score: 9
# Run: 893, exploration: 0.01, score: 9
# Run: 894, exploration: 0.01, score: 9
# Run: 895, exploration: 0.01, score: 9
# Run: 896, exploration: 0.01, score: 9
# Run: 897, exploration: 0.01, score: 10
# Run: 898, exploration: 0.01, score: 8
# Run: 899, exploration: 0.01, score: 12
# Run: 900, exploration: 0.01, score: 9
# Run: 901, exploration: 0.01, score: 8
# Run: 902, exploration: 0.01, score: 9
# Run: 903, exploration: 0.01, score: 9
# Run: 904, exploration: 0.01, score: 10
# Run: 905, exploration: 0.01, score: 9
# Run: 906, exploration: 0.01, score: 8
# Run: 907, exploration: 0.01, score: 9
# Run: 908, exploration: 0.01, score: 9
# Run: 909, exploration: 0.01, score: 10
# Run: 910, exploration: 0.01, score: 10
# Run: 911, exploration: 0.01, score: 10
# Run: 912, exploration: 0.01, score: 10
# Run: 913, exploration: 0.01, score: 10
# Run: 914, exploration: 0.01, score: 8
# Run: 915, exploration: 0.01, score: 9
# Run: 916, exploration: 0.01, score: 9
# Run: 917, exploration: 0.01, score: 10
# Run: 918, exploration: 0.01, score: 10
# Run: 919, exploration: 0.01, score: 10
# Run: 920, exploration: 0.01, score: 10
# Run: 921, exploration: 0.01, score: 9
# Run: 922, exploration: 0.01, score: 9
# Run: 923, exploration: 0.01, score: 10
# Run: 924, exploration: 0.01, score: 8
# Run: 925, exploration: 0.01, score: 10
# Run: 926, exploration: 0.01, score: 9
# Run: 927, exploration: 0.01, score: 10
# Run: 928, exploration: 0.01, score: 8
# Run: 929, exploration: 0.01, score: 9
# Run: 930, exploration: 0.01, score: 8
# Run: 931, exploration: 0.01, score: 9
# Run: 932, exploration: 0.01, score: 10
# Run: 933, exploration: 0.01, score: 9
# Run: 934, exploration: 0.01, score: 9
# Run: 935, exploration: 0.01, score: 9
# Run: 936, exploration: 0.01, score: 9
# Run: 937, exploration: 0.01, score: 10
# Run: 938, exploration: 0.01, score: 10
# Run: 939, exploration: 0.01, score: 10
# Run: 940, exploration: 0.01, score: 10
# Run: 941, exploration: 0.01, score: 9
# Run: 942, exploration: 0.01, score: 9
# Run: 943, exploration: 0.01, score: 10
# Run: 944, exploration: 0.01, score: 9
# Run: 945, exploration: 0.01, score: 10
# Run: 946, exploration: 0.01, score: 10
# Run: 947, exploration: 0.01, score: 8
# Run: 948, exploration: 0.01, score: 9
# Run: 949, exploration: 0.01, score: 10
# Run: 950, exploration: 0.01, score: 10
# Run: 951, exploration: 0.01, score: 9
# Run: 952, exploration: 0.01, score: 9
# Run: 953, exploration: 0.01, score: 10
# Run: 954, exploration: 0.01, score: 10
# Run: 955, exploration: 0.01, score: 10
# Run: 956, exploration: 0.01, score: 10
# Run: 957, exploration: 0.01, score: 8
# Run: 958, exploration: 0.01, score: 9
# Run: 959, exploration: 0.01, score: 8
# Run: 960, exploration: 0.01, score: 10
# Run: 961, exploration: 0.01, score: 10
# Run: 962, exploration: 0.01, score: 10
# Run: 963, exploration: 0.01, score: 8
# Run: 964, exploration: 0.01, score: 8
# Run: 965, exploration: 0.01, score: 10
# Run: 966, exploration: 0.01, score: 12
# Run: 967, exploration: 0.01, score: 10
# Run: 968, exploration: 0.01, score: 10
# Run: 969, exploration: 0.01, score: 8
# Run: 970, exploration: 0.01, score: 9
# Run: 971, exploration: 0.01, score: 8
# Run: 972, exploration: 0.01, score: 8
# Run: 973, exploration: 0.01, score: 9
# Run: 974, exploration: 0.01, score: 10
# Run: 975, exploration: 0.01, score: 10
# Run: 976, exploration: 0.01, score: 9
# Run: 977, exploration: 0.01, score: 10
# Run: 978, exploration: 0.01, score: 9
# Run: 979, exploration: 0.01, score: 9
# Run: 980, exploration: 0.01, score: 9
# Run: 981, exploration: 0.01, score: 10
# Run: 982, exploration: 0.01, score: 10
# Run: 983, exploration: 0.01, score: 9
# Run: 984, exploration: 0.01, score: 10
# Run: 985, exploration: 0.01, score: 8
# Run: 986, exploration: 0.01, score: 10
# Run: 987, exploration: 0.01, score: 9
# Run: 988, exploration: 0.01, score: 8
# Run: 989, exploration: 0.01, score: 9
# Run: 990, exploration: 0.01, score: 9
# Run: 991, exploration: 0.01, score: 8
# Run: 992, exploration: 0.01, score: 10
# Run: 993, exploration: 0.01, score: 8
# Run: 994, exploration: 0.01, score: 10
# Run: 995, exploration: 0.01, score: 9
# Run: 996, exploration: 0.01, score: 9
# Run: 997, exploration: 0.01, score: 10
# Run: 998, exploration: 0.01, score: 8
# Run: 999, exploration: 0.01, score: 9
# Run: 1000, exploration: 0.01, score: 10
# Run: 1001, exploration: 0.01, score: 8
# Run: 1002, exploration: 0.01, score: 9
# Run: 1003, exploration: 0.01, score: 9
# Run: 1004, exploration: 0.01, score: 9
# Run: 1005, exploration: 0.01, score: 9
# Run: 1006, exploration: 0.01, score: 11
# Run: 1007, exploration: 0.01, score: 10
# Run: 1008, exploration: 0.01, score: 9
# Run: 1009, exploration: 0.01, score: 9
# Run: 1010, exploration: 0.01, score: 11
# Run: 1011, exploration: 0.01, score: 10
# Run: 1012, exploration: 0.01, score: 10
# Run: 1013, exploration: 0.01, score: 8
# Run: 1014, exploration: 0.01, score: 8
# Run: 1015, exploration: 0.01, score: 9
# Run: 1016, exploration: 0.01, score: 10
# Run: 1017, exploration: 0.01, score: 10
# Run: 1018, exploration: 0.01, score: 9
# Run: 1019, exploration: 0.01, score: 9
# Run: 1020, exploration: 0.01, score: 9
# Run: 1021, exploration: 0.01, score: 10
# Run: 1022, exploration: 0.01, score: 9
# Run: 1023, exploration: 0.01, score: 9
# Run: 1024, exploration: 0.01, score: 9
# Run: 1025, exploration: 0.01, score: 9
# Run: 1026, exploration: 0.01, score: 10
# Run: 1027, exploration: 0.01, score: 10
# Run: 1028, exploration: 0.01, score: 10
# Run: 1029, exploration: 0.01, score: 10
# Run: 1030, exploration: 0.01, score: 10
# Run: 1031, exploration: 0.01, score: 9
# Run: 1032, exploration: 0.01, score: 10
# Run: 1033, exploration: 0.01, score: 9
# Run: 1034, exploration: 0.01, score: 9
# Run: 1035, exploration: 0.01, score: 10
# Run: 1036, exploration: 0.01, score: 10
# Run: 1037, exploration: 0.01, score: 10
# Run: 1038, exploration: 0.01, score: 10
# Run: 1039, exploration: 0.01, score: 10
# Run: 1040, exploration: 0.01, score: 10
# Run: 1041, exploration: 0.01, score: 10
# Run: 1042, exploration: 0.01, score: 10
# Run: 1043, exploration: 0.01, score: 10
# Run: 1044, exploration: 0.01, score: 9
# Run: 1045, exploration: 0.01, score: 10
# Run: 1046, exploration: 0.01, score: 9
# Run: 1047, exploration: 0.01, score: 10
# Run: 1048, exploration: 0.01, score: 9
# Run: 1049, exploration: 0.01, score: 9
# Run: 1050, exploration: 0.01, score: 10
# Run: 1051, exploration: 0.01, score: 10
# Run: 1052, exploration: 0.01, score: 10
# Run: 1053, exploration: 0.01, score: 10
# Run: 1054, exploration: 0.01, score: 10
# Run: 1055, exploration: 0.01, score: 9
# Run: 1056, exploration: 0.01, score: 9
# Run: 1057, exploration: 0.01, score: 10
# Run: 1058, exploration: 0.01, score: 9
# Run: 1059, exploration: 0.01, score: 9
# Run: 1060, exploration: 0.01, score: 9
# Run: 1061, exploration: 0.01, score: 10
# Run: 1062, exploration: 0.01, score: 10
# Run: 1063, exploration: 0.01, score: 9
# Run: 1064, exploration: 0.01, score: 10
# Run: 1065, exploration: 0.01, score: 9
# Run: 1066, exploration: 0.01, score: 9
# Run: 1067, exploration: 0.01, score: 11
# Run: 1068, exploration: 0.01, score: 10
# Run: 1069, exploration: 0.01, score: 9
# Run: 1070, exploration: 0.01, score: 10
# Run: 1071, exploration: 0.01, score: 10
# Run: 1072, exploration: 0.01, score: 9
# Run: 1073, exploration: 0.01, score: 10
# Run: 1074, exploration: 0.01, score: 8
# Run: 1075, exploration: 0.01, score: 9
# Run: 1076, exploration: 0.01, score: 10
# Run: 1077, exploration: 0.01, score: 9
# Run: 1078, exploration: 0.01, score: 10
# Run: 1079, exploration: 0.01, score: 10
# Run: 1080, exploration: 0.01, score: 10
# Run: 1081, exploration: 0.01, score: 8
# Run: 1082, exploration: 0.01, score: 9
# Run: 1083, exploration: 0.01, score: 9
# Run: 1084, exploration: 0.01, score: 10
# Run: 1085, exploration: 0.01, score: 10
# Run: 1086, exploration: 0.01, score: 9
# Run: 1087, exploration: 0.01, score: 10
# Run: 1088, exploration: 0.01, score: 9
# Run: 1089, exploration: 0.01, score: 8
# Run: 1090, exploration: 0.01, score: 10
# Run: 1091, exploration: 0.01, score: 9
# Run: 1092, exploration: 0.01, score: 10
# Run: 1093, exploration: 0.01, score: 9
# Run: 1094, exploration: 0.01, score: 9
# Run: 1095, exploration: 0.01, score: 8
# Run: 1096, exploration: 0.01, score: 9
# Run: 1097, exploration: 0.01, score: 9
# Run: 1098, exploration: 0.01, score: 9
# Run: 1099, exploration: 0.01, score: 9
# Run: 1100, exploration: 0.01, score: 10
# Run: 1101, exploration: 0.01, score: 10
# Run: 1102, exploration: 0.01, score: 9
# Run: 1103, exploration: 0.01, score: 10
# Run: 1104, exploration: 0.01, score: 10
# Run: 1105, exploration: 0.01, score: 10
# Run: 1106, exploration: 0.01, score: 9
# Run: 1107, exploration: 0.01, score: 9
# Run: 1108, exploration: 0.01, score: 9
# Run: 1109, exploration: 0.01, score: 9
# Run: 1110, exploration: 0.01, score: 10
# Run: 1111, exploration: 0.01, score: 9
# Run: 1112, exploration: 0.01, score: 9
# Run: 1113, exploration: 0.01, score: 10
# Run: 1114, exploration: 0.01, score: 9
# Run: 1115, exploration: 0.01, score: 10
# Run: 1116, exploration: 0.01, score: 10
# Run: 1117, exploration: 0.01, score: 9
# Run: 1118, exploration: 0.01, score: 8
# Run: 1119, exploration: 0.01, score: 10
# Run: 1120, exploration: 0.01, score: 9
# Run: 1121, exploration: 0.01, score: 11
# Run: 1122, exploration: 0.01, score: 10
# Run: 1123, exploration: 0.01, score: 9
# Run: 1124, exploration: 0.01, score: 11
# Run: 1125, exploration: 0.01, score: 9
# Run: 1126, exploration: 0.01, score: 8
# Run: 1127, exploration: 0.01, score: 9
# Run: 1128, exploration: 0.01, score: 10
# Run: 1129, exploration: 0.01, score: 9
# Run: 1130, exploration: 0.01, score: 10
# Run: 1131, exploration: 0.01, score: 9
# Run: 1132, exploration: 0.01, score: 10
# Run: 1133, exploration: 0.01, score: 10
# Run: 1134, exploration: 0.01, score: 10
# Run: 1135, exploration: 0.01, score: 10
# Run: 1136, exploration: 0.01, score: 9
# Run: 1137, exploration: 0.01, score: 9
# Run: 1138, exploration: 0.01, score: 10
# Run: 1139, exploration: 0.01, score: 10
# Run: 1140, exploration: 0.01, score: 10
# Run: 1141, exploration: 0.01, score: 10
# Run: 1142, exploration: 0.01, score: 8
# Run: 1143, exploration: 0.01, score: 8
# Run: 1144, exploration: 0.01, score: 10
# Run: 1145, exploration: 0.01, score: 10
# Run: 1146, exploration: 0.01, score: 10
# Run: 1147, exploration: 0.01, score: 10
# Run: 1148, exploration: 0.01, score: 9
# Run: 1149, exploration: 0.01, score: 9
# Run: 1150, exploration: 0.01, score: 9
# Run: 1151, exploration: 0.01, score: 9
# Run: 1152, exploration: 0.01, score: 10
# Run: 1153, exploration: 0.01, score: 8
# Run: 1154, exploration: 0.01, score: 9
# Run: 1155, exploration: 0.01, score: 9
# Run: 1156, exploration: 0.01, score: 10
# Run: 1157, exploration: 0.01, score: 9
# Run: 1158, exploration: 0.01, score: 10
# Run: 1159, exploration: 0.01, score: 11
# Run: 1160, exploration: 0.01, score: 8
# Run: 1161, exploration: 0.01, score: 8
# Run: 1162, exploration: 0.01, score: 9
# Run: 1163, exploration: 0.01, score: 8
# Run: 1164, exploration: 0.01, score: 9
# Run: 1165, exploration: 0.01, score: 9
# Run: 1166, exploration: 0.01, score: 10
# Run: 1167, exploration: 0.01, score: 9
# Run: 1168, exploration: 0.01, score: 9
# Run: 1169, exploration: 0.01, score: 9
# Run: 1170, exploration: 0.01, score: 9
# Run: 1171, exploration: 0.01, score: 8
# Run: 1172, exploration: 0.01, score: 9
# Run: 1173, exploration: 0.01, score: 10
# Run: 1174, exploration: 0.01, score: 10
# Run: 1175, exploration: 0.01, score: 11
# Run: 1176, exploration: 0.01, score: 10
# Run: 1177, exploration: 0.01, score: 9
# Run: 1178, exploration: 0.01, score: 11
# Run: 1179, exploration: 0.01, score: 10
# Run: 1180, exploration: 0.01, score: 9
# Run: 1181, exploration: 0.01, score: 10
# Run: 1182, exploration: 0.01, score: 9
# Run: 1183, exploration: 0.01, score: 10
# Run: 1184, exploration: 0.01, score: 10
# Run: 1185, exploration: 0.01, score: 10
# Run: 1186, exploration: 0.01, score: 9
# Run: 1187, exploration: 0.01, score: 9
# Run: 1188, exploration: 0.01, score: 10
# Run: 1189, exploration: 0.01, score: 8
# Run: 1190, exploration: 0.01, score: 10
# Run: 1191, exploration: 0.01, score: 10
# Run: 1192, exploration: 0.01, score: 10
# Run: 1193, exploration: 0.01, score: 10
# Run: 1194, exploration: 0.01, score: 9
# Run: 1195, exploration: 0.01, score: 10
# Run: 1196, exploration: 0.01, score: 8
# Run: 1197, exploration: 0.01, score: 9
# Run: 1198, exploration: 0.01, score: 10
# Run: 1199, exploration: 0.01, score: 8
# Run: 1200, exploration: 0.01, score: 9
# Run: 1201, exploration: 0.01, score: 10
# Run: 1202, exploration: 0.01, score: 8
# Run: 1203, exploration: 0.01, score: 9
# Run: 1204, exploration: 0.01, score: 9
# Run: 1205, exploration: 0.01, score: 9
# Run: 1206, exploration: 0.01, score: 9
# Run: 1207, exploration: 0.01, score: 9
# Run: 1208, exploration: 0.01, score: 10
# Run: 1209, exploration: 0.01, score: 8
# Run: 1210, exploration: 0.01, score: 9
# Run: 1211, exploration: 0.01, score: 9
# Run: 1212, exploration: 0.01, score: 10
# Run: 1213, exploration: 0.01, score: 9
# Run: 1214, exploration: 0.01, score: 8
# Run: 1215, exploration: 0.01, score: 9
# Run: 1216, exploration: 0.01, score: 9
# Run: 1217, exploration: 0.01, score: 10
# Run: 1218, exploration: 0.01, score: 9
# Run: 1219, exploration: 0.01, score: 9
# Run: 1220, exploration: 0.01, score: 11
# Run: 1221, exploration: 0.01, score: 9
# Run: 1222, exploration: 0.01, score: 9
# Run: 1223, exploration: 0.01, score: 9
# Run: 1224, exploration: 0.01, score: 9
# Run: 1225, exploration: 0.01, score: 10
# Run: 1226, exploration: 0.01, score: 11
# Run: 1227, exploration: 0.01, score: 9
# Run: 1228, exploration: 0.01, score: 10
# Run: 1229, exploration: 0.01, score: 9
# Run: 1230, exploration: 0.01, score: 8
# ...
# Run: 2468, exploration: 0.01, score: 10
# Run: 2469, exploration: 0.01, score: 9
# Run: 2470, exploration: 0.01, score: 9
# Run: 2471, exploration: 0.01, score: 10
# Run: 2472, exploration: 0.01, score: 10
# Run: 2473, exploration: 0.01, score: 9
# Run: 2474, exploration: 0.01, score: 9
# Run: 2475, exploration: 0.01, score: 10
# Run: 2476, exploration: 0.01, score: 8
# Run: 2477, exploration: 0.01, score: 9
# Run: 2478, exploration: 0.01, score: 10
# Run: 2479, exploration: 0.01, score: 8
# Run: 2480, exploration: 0.01, score: 9
# Run: 2481, exploration: 0.01, score: 10
# Run: 2482, exploration: 0.01, score: 10
# Run: 2483, exploration: 0.01, score: 10
# Run: 2484, exploration: 0.01, score: 9
# Run: 2485, exploration: 0.01, score: 9
# Run: 2486, exploration: 0.01, score: 9
# Run: 2487, exploration: 0.01, score: 8
# Run: 2488, exploration: 0.01, score: 8
# Run: 2489, exploration: 0.01, score: 9
# Run: 2490, exploration: 0.01, score: 11
# Run: 2491, exploration: 0.01, score: 9
# Run: 2492, exploration: 0.01, score: 10
# Run: 2493, exploration: 0.01, score: 10
# Run: 2494, exploration: 0.01, score: 10
# Run: 2495, exploration: 0.01, score: 9
# Run: 2496, exploration: 0.01, score: 9
# Run: 2497, exploration: 0.01, score: 8
# Run: 2498, exploration: 0.01, score: 9
# Run: 2499, exploration: 0.01, score: 10
# Run: 2500, exploration: 0.01, score: 10
# Run: 2501, exploration: 0.01, score: 8
# Run: 2502, exploration: 0.01, score: 9
# Run: 2503, exploration: 0.01, score: 10
# Run: 2504, exploration: 0.01, score: 9
# Run: 2505, exploration: 0.01, score: 9
# Run: 2506, exploration: 0.01, score: 8
# Run: 2507, exploration: 0.01, score: 9
# Run: 2508, exploration: 0.01, score: 10
# Run: 2509, exploration: 0.01, score: 8
# Run: 2510, exploration: 0.01, score: 10
# Run: 2511, exploration: 0.01, score: 9
# Run: 2512, exploration: 0.01, score: 8
# Run: 2513, exploration: 0.01, score: 8
# Run: 2514, exploration: 0.01, score: 8
# Run: 2515, exploration: 0.01, score: 12
# Run: 2516, exploration: 0.01, score: 9
# Run: 2517, exploration: 0.01, score: 9
# Run: 2518, exploration: 0.01, score: 10
# Run: 2519, exploration: 0.01, score: 9
# Run: 2520, exploration: 0.01, score: 9
# Run: 2521, exploration: 0.01, score: 9
# Run: 2522, exploration: 0.01, score: 9
# Run: 2523, exploration: 0.01, score: 10
# Run: 2524, exploration: 0.01, score: 9
# Run: 2525, exploration: 0.01, score: 10
# Run: 2526, exploration: 0.01, score: 10
# Run: 2527, exploration: 0.01, score: 10
# Run: 2528, exploration: 0.01, score: 9
# Run: 2529, exploration: 0.01, score: 10
# Run: 2530, exploration: 0.01, score: 10
# Run: 2531, exploration: 0.01, score: 9
# Run: 2532, exploration: 0.01, score: 10
# Run: 2533, exploration: 0.01, score: 9
# Run: 2534, exploration: 0.01, score: 10
# Run: 2535, exploration: 0.01, score: 9
# Run: 2536, exploration: 0.01, score: 8
# Run: 2537, exploration: 0.01, score: 10
# Run: 2538, exploration: 0.01, score: 11
# Run: 2539, exploration: 0.01, score: 9
# Run: 2540, exploration: 0.01, score: 9
# Run: 2541, exploration: 0.01, score: 9
# Run: 2542, exploration: 0.01, score: 10
# Run: 2543, exploration: 0.01, score: 9
# Run: 2544, exploration: 0.01, score: 8
# Run: 2545, exploration: 0.01, score: 9
# Run: 2546, exploration: 0.01, score: 10
# Run: 2547, exploration: 0.01, score: 8
# Run: 2548, exploration: 0.01, score: 10
# Run: 2549, exploration: 0.01, score: 10
# Run: 2550, exploration: 0.01, score: 8
# Run: 2551, exploration: 0.01, score: 10
# Run: 2552, exploration: 0.01, score: 10
# Run: 2553, exploration: 0.01, score: 9
# Run: 2554, exploration: 0.01, score: 9
# Run: 2555, exploration: 0.01, score: 11
# Run: 2556, exploration: 0.01, score: 9
# Run: 2557, exploration: 0.01, score: 9
# Run: 2558, exploration: 0.01, score: 8
# Run: 2559, exploration: 0.01, score: 9
# Run: 2560, exploration: 0.01, score: 9
# Run: 2561, exploration: 0.01, score: 9
# Run: 2562, exploration: 0.01, score: 10
# Run: 2563, exploration: 0.01, score: 10
# Run: 2564, exploration: 0.01, score: 10
# Run: 2565, exploration: 0.01, score: 9
# Run: 2566, exploration: 0.01, score: 10
# Run: 2567, exploration: 0.01, score: 9
# Run: 2568, exploration: 0.01, score: 10
# Run: 2569, exploration: 0.01, score: 10
# Run: 2570, exploration: 0.01, score: 10
# Run: 2571, exploration: 0.01, score: 8
# Run: 2572, exploration: 0.01, score: 10
# Run: 2573, exploration: 0.01, score: 11
# Run: 2574, exploration: 0.01, score: 9
# Run: 2575, exploration: 0.01, score: 10
# Run: 2576, exploration: 0.01, score: 10
# Run: 2577, exploration: 0.01, score: 10
# Run: 2578, exploration: 0.01, score: 8
# Run: 2579, exploration: 0.01, score: 9
# Run: 2580, exploration: 0.01, score: 9
# Run: 2581, exploration: 0.01, score: 9
# Run: 2582, exploration: 0.01, score: 9
# Run: 2583, exploration: 0.01, score: 11
# Run: 2584, exploration: 0.01, score: 8
# Run: 2585, exploration: 0.01, score: 10
# Run: 2586, exploration: 0.01, score: 9
# Run: 2587, exploration: 0.01, score: 11
# Run: 2588, exploration: 0.01, score: 10
# Run: 2589, exploration: 0.01, score: 9
# Run: 2590, exploration: 0.01, score: 10
# Run: 2591, exploration: 0.01, score: 10
# Run: 2592, exploration: 0.01, score: 10
# Run: 2593, exploration: 0.01, score: 10
# Run: 2594, exploration: 0.01, score: 10
# Run: 2595, exploration: 0.01, score: 9
# Run: 2596, exploration: 0.01, score: 10
# Run: 2597, exploration: 0.01, score: 10
# Run: 2598, exploration: 0.01, score: 9
# Run: 2599, exploration: 0.01, score: 9
# Run: 2600, exploration: 0.01, score: 10
# Run: 2601, exploration: 0.01, score: 10
# Run: 2602, exploration: 0.01, score: 9
# Run: 2603, exploration: 0.01, score: 10
# Run: 2604, exploration: 0.01, score: 9
# Run: 2605, exploration: 0.01, score: 10
# Run: 2606, exploration: 0.01, score: 9
# Run: 2607, exploration: 0.01, score: 9
# Run: 2608, exploration: 0.01, score: 10
# Run: 2609, exploration: 0.01, score: 10
# Run: 2610, exploration: 0.01, score: 10
# Run: 2611, exploration: 0.01, score: 8
# Run: 2612, exploration: 0.01, score: 8
# Run: 2613, exploration: 0.01, score: 12
# Run: 2614, exploration: 0.01, score: 9
# Run: 2615, exploration: 0.01, score: 10
# Run: 2616, exploration: 0.01, score: 8
# Run: 2617, exploration: 0.01, score: 9
# Run: 2618, exploration: 0.01, score: 10
# Run: 2619, exploration: 0.01, score: 11
# Run: 2620, exploration: 0.01, score: 10
# Run: 2621, exploration: 0.01, score: 9
# Run: 2622, exploration: 0.01, score: 10
# Run: 2623, exploration: 0.01, score: 9
# Run: 2624, exploration: 0.01, score: 10
# Run: 2625, exploration: 0.01, score: 9
# Run: 2626, exploration: 0.01, score: 11
# Run: 2627, exploration: 0.01, score: 10
# Run: 2628, exploration: 0.01, score: 10
# Run: 2629, exploration: 0.01, score: 8
# Run: 2630, exploration: 0.01, score: 8
# Run: 2631, exploration: 0.01, score: 11
# Run: 2632, exploration: 0.01, score: 9
# Run: 2633, exploration: 0.01, score: 9
# Run: 2634, exploration: 0.01, score: 10
# Run: 2635, exploration: 0.01, score: 10
# Run: 2636, exploration: 0.01, score: 9
# Run: 2637, exploration: 0.01, score: 9
# Run: 2638, exploration: 0.01, score: 8
# Run: 2639, exploration: 0.01, score: 9
# Run: 2640, exploration: 0.01, score: 9
# Run: 2641, exploration: 0.01, score: 9
# Run: 2642, exploration: 0.01, score: 10
# Run: 2643, exploration: 0.01, score: 9
# Run: 2644, exploration: 0.01, score: 9
# Run: 2645, exploration: 0.01, score: 10
# Run: 2646, exploration: 0.01, score: 9
# Run: 2647, exploration: 0.01, score: 9
# Run: 2648, exploration: 0.01, score: 9
# Run: 2649, exploration: 0.01, score: 10
# Run: 2650, exploration: 0.01, score: 8
# Run: 2651, exploration: 0.01, score: 9
# Run: 2652, exploration: 0.01, score: 10
# Run: 2653, exploration: 0.01, score: 8
# Run: 2654, exploration: 0.01, score: 10
# Run: 2655, exploration: 0.01, score: 10
# Run: 2656, exploration: 0.01, score: 10
# Run: 2657, exploration: 0.01, score: 9
# Run: 2658, exploration: 0.01, score: 9
# Run: 2659, exploration: 0.01, score: 11
# Run: 2660, exploration: 0.01, score: 9
# Run: 2661, exploration: 0.01, score: 9
# Run: 2662, exploration: 0.01, score: 10
# Run: 2663, exploration: 0.01, score: 9
# Run: 2664, exploration: 0.01, score: 10
# Run: 2665, exploration: 0.01, score: 10
# Run: 2666, exploration: 0.01, score: 9
# Run: 2667, exploration: 0.01, score: 8
# Run: 2668, exploration: 0.01, score: 8
# Run: 2669, exploration: 0.01, score: 9
# Run: 2670, exploration: 0.01, score: 10
# Run: 2671, exploration: 0.01, score: 9
# Run: 2672, exploration: 0.01, score: 10
# Run: 2673, exploration: 0.01, score: 10
# Run: 2674, exploration: 0.01, score: 9
# Run: 2675, exploration: 0.01, score: 8
# Run: 2676, exploration: 0.01, score: 10
# Run: 2677, exploration: 0.01, score: 10
# Run: 2678, exploration: 0.01, score: 10
# Run: 2679, exploration: 0.01, score: 9
# Run: 2680, exploration: 0.01, score: 8
# Run: 2681, exploration: 0.01, score: 9
# Run: 2682, exploration: 0.01, score: 11
# Run: 2683, exploration: 0.01, score: 9
# Run: 2684, exploration: 0.01, score: 9
# Run: 2685, exploration: 0.01, score: 9
# Run: 2686, exploration: 0.01, score: 9
# Run: 2687, exploration: 0.01, score: 10
# Run: 2688, exploration: 0.01, score: 8
# Run: 2689, exploration: 0.01, score: 10
# Run: 2690, exploration: 0.01, score: 9
# Run: 2691, exploration: 0.01, score: 10
# Run: 2692, exploration: 0.01, score: 10
# Run: 2693, exploration: 0.01, score: 9
# Run: 2694, exploration: 0.01, score: 10
# Run: 2695, exploration: 0.01, score: 8
# Run: 2696, exploration: 0.01, score: 10
# Run: 2697, exploration: 0.01, score: 8
# Run: 2698, exploration: 0.01, score: 9
# Run: 2699, exploration: 0.01, score: 9
# Run: 2700, exploration: 0.01, score: 9
# Run: 2701, exploration: 0.01, score: 9
# Run: 2702, exploration: 0.01, score: 9
# Run: 2703, exploration: 0.01, score: 8
# Run: 2704, exploration: 0.01, score: 10
# Run: 2705, exploration: 0.01, score: 10
# Run: 2706, exploration: 0.01, score: 9
# Run: 2707, exploration: 0.01, score: 9
# Run: 2708, exploration: 0.01, score: 11
# Run: 2709, exploration: 0.01, score: 9
# Run: 2710, exploration: 0.01, score: 8
# Run: 2711, exploration: 0.01, score: 10
# Run: 2712, exploration: 0.01, score: 10
# Run: 2713, exploration: 0.01, score: 10
# Run: 2714, exploration: 0.01, score: 9
# Run: 2715, exploration: 0.01, score: 9
# Run: 2716, exploration: 0.01, score: 9
# Run: 2717, exploration: 0.01, score: 9
# Run: 2718, exploration: 0.01, score: 9
# Run: 2719, exploration: 0.01, score: 10
# Run: 2720, exploration: 0.01, score: 9
# Run: 2721, exploration: 0.01, score: 9
# Run: 2722, exploration: 0.01, score: 10
# Run: 2723, exploration: 0.01, score: 10
# Run: 2724, exploration: 0.01, score: 9
# Run: 2725, exploration: 0.01, score: 9
# Run: 2726, exploration: 0.01, score: 10
# Run: 2727, exploration: 0.01, score: 9
# Run: 2728, exploration: 0.01, score: 9
# Run: 2729, exploration: 0.01, score: 9
# Run: 2730, exploration: 0.01, score: 9
# Run: 2731, exploration: 0.01, score: 11
# Run: 2732, exploration: 0.01, score: 9
# Run: 2733, exploration: 0.01, score: 9
# Run: 2734, exploration: 0.01, score: 10
# Run: 2735, exploration: 0.01, score: 9
# Run: 2736, exploration: 0.01, score: 10
# Run: 2737, exploration: 0.01, score: 10
# Run: 2738, exploration: 0.01, score: 10
# Run: 2739, exploration: 0.01, score: 10
# Run: 2740, exploration: 0.01, score: 9
# Run: 2741, exploration: 0.01, score: 10
# Run: 2742, exploration: 0.01, score: 10
# Run: 2743, exploration: 0.01, score: 10
# Run: 2744, exploration: 0.01, score: 8
# Run: 2745, exploration: 0.01, score: 10
# Run: 2746, exploration: 0.01, score: 9
# Run: 2747, exploration: 0.01, score: 9
# Run: 2748, exploration: 0.01, score: 8
# Run: 2749, exploration: 0.01, score: 8
# Run: 2750, exploration: 0.01, score: 9
# Run: 2751, exploration: 0.01, score: 10
# Run: 2752, exploration: 0.01, score: 9
# Run: 2753, exploration: 0.01, score: 9
# Run: 2754, exploration: 0.01, score: 10
# Run: 2755, exploration: 0.01, score: 9
# Run: 2756, exploration: 0.01, score: 10
# Run: 2757, exploration: 0.01, score: 8
# Run: 2758, exploration: 0.01, score: 8
# Run: 2759, exploration: 0.01, score: 10
# Run: 2760, exploration: 0.01, score: 9
# Run: 2761, exploration: 0.01, score: 9
# Run: 2762, exploration: 0.01, score: 9
# Run: 2763, exploration: 0.01, score: 9
# Run: 2764, exploration: 0.01, score: 10
# Run: 2765, exploration: 0.01, score: 9
# Run: 2766, exploration: 0.01, score: 9
# Run: 2767, exploration: 0.01, score: 9
# Run: 2768, exploration: 0.01, score: 9
# Run: 2769, exploration: 0.01, score: 9
# Run: 2770, exploration: 0.01, score: 10
# Run: 2771, exploration: 0.01, score: 8
# Run: 2772, exploration: 0.01, score: 9
# Run: 2773, exploration: 0.01, score: 10
# Run: 2774, exploration: 0.01, score: 9
# Run: 2775, exploration: 0.01, score: 9
# Run: 2776, exploration: 0.01, score: 10
# Run: 2777, exploration: 0.01, score: 10
# Run: 2778, exploration: 0.01, score: 9
# Run: 2779, exploration: 0.01, score: 9
# Run: 2780, exploration: 0.01, score: 11
# Run: 2781, exploration: 0.01, score: 9
# Run: 2782, exploration: 0.01, score: 9
# Run: 2783, exploration: 0.01, score: 9
# Run: 2784, exploration: 0.01, score: 9
# Run: 2785, exploration: 0.01, score: 10
# Run: 2786, exploration: 0.01, score: 9
# Run: 2787, exploration: 0.01, score: 10
# Run: 2788, exploration: 0.01, score: 10
# Run: 2789, exploration: 0.01, score: 9
# Run: 2790, exploration: 0.01, score: 9
# Run: 2791, exploration: 0.01, score: 10
# Run: 2792, exploration: 0.01, score: 10
# Run: 2793, exploration: 0.01, score: 9
# Run: 2794, exploration: 0.01, score: 9
# Run: 2795, exploration: 0.01, score: 9
# Run: 2796, exploration: 0.01, score: 9
# Run: 2797, exploration: 0.01, score: 11
# Run: 2798, exploration: 0.01, score: 9
# Run: 2799, exploration: 0.01, score: 9
# Run: 2800, exploration: 0.01, score: 9
# Run: 2801, exploration: 0.01, score: 10
# Run: 2802, exploration: 0.01, score: 9
# Run: 2803, exploration: 0.01, score: 10
# Run: 2804, exploration: 0.01, score: 9
# Run: 2805, exploration: 0.01, score: 10
# Run: 2806, exploration: 0.01, score: 10
# Run: 2807, exploration: 0.01, score: 9
# Run: 2808, exploration: 0.01, score: 10
# Run: 2809, exploration: 0.01, score: 10
# Run: 2810, exploration: 0.01, score: 8
# Run: 2811, exploration: 0.01, score: 8
# Run: 2812, exploration: 0.01, score: 10
# Run: 2813, exploration: 0.01, score: 8
# Run: 2814, exploration: 0.01, score: 10
# Run: 2815, exploration: 0.01, score: 10
# Run: 2816, exploration: 0.01, score: 9
# Run: 2817, exploration: 0.01, score: 8
# Run: 2818, exploration: 0.01, score: 9
# Run: 2819, exploration: 0.01, score: 9
# Run: 2820, exploration: 0.01, score: 9
# Run: 2821, exploration: 0.01, score: 8
# Run: 2822, exploration: 0.01, score: 9
# Run: 2823, exploration: 0.01, score: 9
# Run: 2824, exploration: 0.01, score: 10
# Run: 2825, exploration: 0.01, score: 8
# Run: 2826, exploration: 0.01, score: 10
# Run: 2827, exploration: 0.01, score: 10
# Run: 2828, exploration: 0.01, score: 8
# Run: 2829, exploration: 0.01, score: 10
# Run: 2830, exploration: 0.01, score: 10
# Run: 2831, exploration: 0.01, score: 10
# Run: 2832, exploration: 0.01, score: 9
# Run: 2833, exploration: 0.01, score: 8
# Run: 2834, exploration: 0.01, score: 8
# Run: 2835, exploration: 0.01, score: 10
# Run: 2836, exploration: 0.01, score: 9
# Run: 2837, exploration: 0.01, score: 8
# Run: 2838, exploration: 0.01, score: 9
# Run: 2839, exploration: 0.01, score: 9
# Run: 2840, exploration: 0.01, score: 10
# Run: 2841, exploration: 0.01, score: 10
# Run: 2842, exploration: 0.01, score: 10
# Run: 2843, exploration: 0.01, score: 9
# Run: 2844, exploration: 0.01, score: 8
# Run: 2845, exploration: 0.01, score: 10
# Run: 2846, exploration: 0.01, score: 10
# Run: 2847, exploration: 0.01, score: 10
# Run: 2848, exploration: 0.01, score: 8
# Run: 2849, exploration: 0.01, score: 9
# Run: 2850, exploration: 0.01, score: 11
# Run: 2851, exploration: 0.01, score: 9
# Run: 2852, exploration: 0.01, score: 9
# Run: 2853, exploration: 0.01, score: 10
# Run: 2854, exploration: 0.01, score: 8
# Run: 2855, exploration: 0.01, score: 9
# Run: 2856, exploration: 0.01, score: 9
# Run: 2857, exploration: 0.01, score: 10
# Run: 2858, exploration: 0.01, score: 9
# Run: 2859, exploration: 0.01, score: 9
# Run: 2860, exploration: 0.01, score: 9
# Run: 2861, exploration: 0.01, score: 9
# Run: 2862, exploration: 0.01, score: 9
# Run: 2863, exploration: 0.01, score: 8
# Run: 2864, exploration: 0.01, score: 8
# Run: 2865, exploration: 0.01, score: 9
# Run: 2866, exploration: 0.01, score: 8
# Run: 2867, exploration: 0.01, score: 8
# Run: 2868, exploration: 0.01, score: 8
# Run: 2869, exploration: 0.01, score: 10
# Run: 2870, exploration: 0.01, score: 9
# Run: 2871, exploration: 0.01, score: 10
# Run: 2872, exploration: 0.01, score: 9

# %%
env.close()
