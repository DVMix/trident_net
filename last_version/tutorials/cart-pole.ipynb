# %%
# !pip3 install gym
# !apt install freeglut3-dev -y
# Out:
# Requirement already satisfied: gym in /usr/local/lib/python3.6/dist-packages
# Requirement already satisfied: numpy>=1.10.4 in /usr/local/lib/python3.6/dist-packages (from gym)
# Requirement already satisfied: cloudpickle<1.7.0,>=1.2.0 in /usr/local/lib/python3.6/dist-packages (from gym)
# Requirement already satisfied: pyglet<=1.5.0,>=1.4.0 in /usr/local/lib/python3.6/dist-packages (from gym)
# Requirement already satisfied: scipy in /usr/local/lib/python3.6/dist-packages (from gym)
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from pyglet<=1.5.0,>=1.4.0->gym)
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   libdrm-dev libgl1-mesa-dev libgles1 libgles2 libglu1-mesa-dev
#   libglvnd-core-dev libglvnd-dev libice-dev libice6 libopengl0
#   libpthread-stubs0-dev libsm-dev libsm6 libx11-dev libx11-doc libx11-xcb-dev
#   libxau-dev libxcb-dri2-0-dev libxcb-dri3-dev libxcb-glx0-dev
#   libxcb-present-dev libxcb-randr0 libxcb-randr0-dev libxcb-render0-dev
#   libxcb-shape0-dev libxcb-sync-dev libxcb-xfixes0-dev libxcb1-dev
#   libxdamage-dev libxdmcp-dev libxext-dev libxfixes-dev libxshmfence-dev
#   libxt-dev libxt6 libxxf86vm-dev mesa-common-dev x11proto-core-dev
#   x11proto-damage-dev x11proto-dev x11proto-fixes-dev x11proto-xext-dev
#   x11proto-xf86vidmode-dev xorg-sgml-doctools xtrans-dev
# Suggested packages:
#   libice-doc libsm-doc libxcb-doc libxext-doc libxt-doc
# The following NEW packages will be installed:
#   freeglut3-dev libdrm-dev libgl1-mesa-dev libgles1 libgles2 libglu1-mesa-dev
#   libglvnd-core-dev libglvnd-dev libice-dev libice6 libopengl0
#   libpthread-stubs0-dev libsm-dev libsm6 libx11-dev libx11-doc libx11-xcb-dev
#   libxau-dev libxcb-dri2-0-dev libxcb-dri3-dev libxcb-glx0-dev
#   libxcb-present-dev libxcb-randr0 libxcb-randr0-dev libxcb-render0-dev
#   libxcb-shape0-dev libxcb-sync-dev libxcb-xfixes0-dev libxcb1-dev
#   libxdamage-dev libxdmcp-dev libxext-dev libxfixes-dev libxshmfence-dev
#   libxt-dev libxt6 libxxf86vm-dev mesa-common-dev x11proto-core-dev
#   x11proto-damage-dev x11proto-dev x11proto-fixes-dev x11proto-xext-dev
#   x11proto-xf86vidmode-dev xorg-sgml-doctools xtrans-dev
# 0 upgraded, 46 newly installed, 0 to remove and 102 not upgraded.
# Need to get 5387 kB of archives.
# After this operation, 28.0 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/main amd64 libice6 amd64 2:1.0.9-2 [40.2 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic/main amd64 libsm6 amd64 2:1.2.2-1 [15.8 kB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic/main amd64 xorg-sgml-doctools all 1:1.11-1 [12.9 kB]
# Get:4 http://archive.ubuntu.com/ubuntu bionic/main amd64 x11proto-dev all 2018.4-4 [251 kB]
# Get:5 http://archive.ubuntu.com/ubuntu bionic/main amd64 x11proto-core-dev all 2018.4-4 [2620 B]
# Get:6 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libxau-dev amd64 1:1.0.8-1ubuntu1 [9476 B]
# Get:7 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxdmcp-dev amd64 1:1.1.2-3 [25.1 kB]
# Get:8 http://archive.ubuntu.com/ubuntu bionic/main amd64 xtrans-dev all 1.3.5-1 [70.5 kB]
# Get:9 http://archive.ubuntu.com/ubuntu bionic/main amd64 libpthread-stubs0-dev amd64 0.3-4 [4068 B]
# Get:10 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libxcb1-dev amd64 1.13-2~ubuntu18.04 [80.0 kB]
# Get:11 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libx11-dev amd64 2:1.6.4-3ubuntu0.3 [643 kB]
# Get:12 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libdrm-dev amd64 2.4.101-2~18.04.1 [126 kB]
# Get:13 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 mesa-common-dev amd64 20.0.8-0ubuntu1~18.04.1 [741 kB]
# Get:14 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libglvnd-core-dev amd64 1.0.0-2ubuntu2.3 [12.8 kB]
# Get:15 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libgles1 amd64 1.0.0-2ubuntu2.3 [11.2 kB]
# Get:16 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libgles2 amd64 1.0.0-2ubuntu2.3 [17.3 kB]
# Get:17 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libopengl0 amd64 1.0.0-2ubuntu2.3 [31.3 kB]
# Get:18 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libglvnd-dev amd64 1.0.0-2ubuntu2.3 [3416 B]
# Get:19 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libx11-xcb-dev amd64 2:1.6.4-3ubuntu0.3 [9760 B]
# Get:20 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libxcb-dri3-dev amd64 1.13-2~ubuntu18.04 [7384 B]
# Get:21 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libxcb-randr0 amd64 1.13-2~ubuntu18.04 [16.4 kB]
# Get:22 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libxcb-render0-dev amd64 1.13-2~ubuntu18.04 [18.4 kB]
# Get:23 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libxcb-randr0-dev amd64 1.13-2~ubuntu18.04 [20.4 kB]
# Get:24 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libxcb-shape0-dev amd64 1.13-2~ubuntu18.04 [7144 B]
# Get:25 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libxcb-xfixes0-dev amd64 1.13-2~ubuntu18.04 [11.7 kB]
# Get:26 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libxcb-sync-dev amd64 1.13-2~ubuntu18.04 [10.6 kB]
# Get:27 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libxcb-present-dev amd64 1.13-2~ubuntu18.04 [6972 B]
# Get:28 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxshmfence-dev amd64 1.3-1 [3692 B]
# Get:29 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libxcb-dri2-0-dev amd64 1.13-2~ubuntu18.04 [8472 B]
# Get:30 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libxcb-glx0-dev amd64 1.13-2~ubuntu18.04 [27.9 kB]
# Get:31 http://archive.ubuntu.com/ubuntu bionic/main amd64 x11proto-fixes-dev all 1:2018.4-4 [2620 B]
# Get:32 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxfixes-dev amd64 1:5.0.3-1 [11.0 kB]
# Get:33 http://archive.ubuntu.com/ubuntu bionic/main amd64 x11proto-damage-dev all 1:2018.4-4 [2620 B]
# Get:34 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxdamage-dev amd64 1:1.1.4-3 [5028 B]
# Get:35 http://archive.ubuntu.com/ubuntu bionic/main amd64 x11proto-xext-dev all 2018.4-4 [2620 B]
# Get:36 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxext-dev amd64 2:1.3.3-1 [82.1 kB]
# Get:37 http://archive.ubuntu.com/ubuntu bionic/main amd64 x11proto-xf86vidmode-dev all 2018.4-4 [2632 B]
# Get:38 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxxf86vm-dev amd64 1:1.1.4-1 [13.3 kB]
# Get:39 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libgl1-mesa-dev amd64 20.0.8-0ubuntu1~18.04.1 [6180 B]
# Get:40 http://archive.ubuntu.com/ubuntu bionic/main amd64 libglu1-mesa-dev amd64 9.0.0-2.1build1 [206 kB]
# Get:41 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxt6 amd64 1:1.1.5-1 [160 kB]
# Get:42 http://archive.ubuntu.com/ubuntu bionic/main amd64 libice-dev amd64 2:1.0.9-2 [46.8 kB]
# Get:43 http://archive.ubuntu.com/ubuntu bionic/main amd64 libsm-dev amd64 2:1.2.2-1 [16.2 kB]
# Get:44 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxt-dev amd64 1:1.1.5-1 [395 kB]
# Get:45 http://archive.ubuntu.com/ubuntu bionic/universe amd64 freeglut3-dev amd64 2.8.1-3 [124 kB]
# Get:46 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libx11-doc all 2:1.6.4-3ubuntu0.3 [2065 kB]
# Fetched 5387 kB in 1s (5413 kB/s)
# debconf: delaying package configuration, since apt-utils is not installed
#
# 78Selecting previously unselected package libice6:amd64.
# (Reading database ... 22528 files and directories currently installed.)
# Preparing to unpack .../00-libice6_2%3a1.0.9-2_amd64.deb ...
# 7Progress: [  0%] [..........................................................] 8Unpacking libice6:amd64 (2:1.0.9-2) ...
# 7Progress: [  1%] [..........................................................] 8Selecting previously unselected package libsm6:amd64.
# Preparing to unpack .../01-libsm6_2%3a1.2.2-1_amd64.deb ...
# Unpacking libsm6:amd64 (2:1.2.2-1) ...
# 7Progress: [  2%] [#.........................................................] 8Selecting previously unselected package xorg-sgml-doctools.
# Preparing to unpack .../02-xorg-sgml-doctools_1%3a1.11-1_all.deb ...
# 7Progress: [  3%] [#.........................................................] 8Unpacking xorg-sgml-doctools (1:1.11-1) ...
# Selecting previously unselected package x11proto-dev.
# Preparing to unpack .../03-x11proto-dev_2018.4-4_all.deb ...
# 7Progress: [  4%] [##........................................................] 8Unpacking x11proto-dev (2018.4-4) ...
# 7Progress: [  5%] [###.......................................................] 8Selecting previously unselected package x11proto-core-dev.
# Preparing to unpack .../04-x11proto-core-dev_2018.4-4_all.deb ...
# Unpacking x11proto-core-dev (2018.4-4) ...
# 7Progress: [  6%] [###.......................................................] 8Selecting previously unselected package libxau-dev:amd64.
# Preparing to unpack .../05-libxau-dev_1%3a1.0.8-1ubuntu1_amd64.deb ...
# Unpacking libxau-dev:amd64 (1:1.0.8-1ubuntu1) ...
# 7Progress: [  7%] [####......................................................] 8Selecting previously unselected package libxdmcp-dev:amd64.
# Preparing to unpack .../06-libxdmcp-dev_1%3a1.1.2-3_amd64.deb ...
# 7Progress: [  8%] [####......................................................] 8Unpacking libxdmcp-dev:amd64 (1:1.1.2-3) ...
# 7Progress: [  9%] [#####.....................................................] 8Selecting previously unselected package xtrans-dev.
# Preparing to unpack .../07-xtrans-dev_1.3.5-1_all.deb ...
# Unpacking xtrans-dev (1.3.5-1) ...
# 7Progress: [ 10%] [######....................................................] 8Selecting previously unselected package libpthread-stubs0-dev:amd64.
# Preparing to unpack .../08-libpthread-stubs0-dev_0.3-4_amd64.deb ...
# Unpacking libpthread-stubs0-dev:amd64 (0.3-4) ...
# 7Progress: [ 11%] [######....................................................] 8Selecting previously unselected package libxcb1-dev:amd64.
# Preparing to unpack .../09-libxcb1-dev_1.13-2~ubuntu18.04_amd64.deb ...
# 7Progress: [ 12%] [#######...................................................] 8Unpacking libxcb1-dev:amd64 (1.13-2~ubuntu18.04) ...
# Selecting previously unselected package libx11-dev:amd64.
# Preparing to unpack .../10-libx11-dev_2%3a1.6.4-3ubuntu0.3_amd64.deb ...
# 7Progress: [ 13%] [#######...................................................] 8Unpacking libx11-dev:amd64 (2:1.6.4-3ubuntu0.3) ...
# 7Progress: [ 14%] [########..................................................] 8Selecting previously unselected package libdrm-dev:amd64.
# Preparing to unpack .../11-libdrm-dev_2.4.101-2~18.04.1_amd64.deb ...
# Unpacking libdrm-dev:amd64 (2.4.101-2~18.04.1) ...
# 7Progress: [ 15%] [########..................................................] 8Selecting previously unselected package mesa-common-dev:amd64.
# Preparing to unpack .../12-mesa-common-dev_20.0.8-0ubuntu1~18.04.1_amd64.deb ...
# 7Progress: [ 16%] [#########.................................................] 8Unpacking mesa-common-dev:amd64 (20.0.8-0ubuntu1~18.04.1) ...
# Selecting previously unselected package libglvnd-core-dev:amd64.
# Preparing to unpack .../13-libglvnd-core-dev_1.0.0-2ubuntu2.3_amd64.deb ...
# 7Progress: [ 17%] [##########................................................] 8Unpacking libglvnd-core-dev:amd64 (1.0.0-2ubuntu2.3) ...
# 7Progress: [ 18%] [##########................................................] 8Selecting previously unselected package libgles1:amd64.
# Preparing to unpack .../14-libgles1_1.0.0-2ubuntu2.3_amd64.deb ...
# Unpacking libgles1:amd64 (1.0.0-2ubuntu2.3) ...
# 7Progress: [ 19%] [###########...............................................] 8Selecting previously unselected package libgles2:amd64.
# Preparing to unpack .../15-libgles2_1.0.0-2ubuntu2.3_amd64.deb ...
# Unpacking libgles2:amd64 (1.0.0-2ubuntu2.3) ...
# 7Progress: [ 20%] [###########...............................................] 8Selecting previously unselected package libopengl0:amd64.
# Preparing to unpack .../16-libopengl0_1.0.0-2ubuntu2.3_amd64.deb ...
# 7Progress: [ 21%] [############..............................................] 8Unpacking libopengl0:amd64 (1.0.0-2ubuntu2.3) ...
# 7Progress: [ 22%] [############..............................................] 8Selecting previously unselected package libglvnd-dev:amd64.
# Preparing to unpack .../17-libglvnd-dev_1.0.0-2ubuntu2.3_amd64.deb ...
# Unpacking libglvnd-dev:amd64 (1.0.0-2ubuntu2.3) ...
# 7Progress: [ 23%] [#############.............................................] 8Selecting previously unselected package libx11-xcb-dev:amd64.
# Preparing to unpack .../18-libx11-xcb-dev_2%3a1.6.4-3ubuntu0.3_amd64.deb ...
# Unpacking libx11-xcb-dev:amd64 (2:1.6.4-3ubuntu0.3) ...
# 7Progress: [ 24%] [##############............................................] 8Selecting previously unselected package libxcb-dri3-dev:amd64.
# Preparing to unpack .../19-libxcb-dri3-dev_1.13-2~ubuntu18.04_amd64.deb ...
# 7Progress: [ 25%] [##############............................................] 8Unpacking libxcb-dri3-dev:amd64 (1.13-2~ubuntu18.04) ...
# Selecting previously unselected package libxcb-randr0:amd64.
# Preparing to unpack .../20-libxcb-randr0_1.13-2~ubuntu18.04_amd64.deb ...
# 7Progress: [ 26%] [###############...........................................] 8Unpacking libxcb-randr0:amd64 (1.13-2~ubuntu18.04) ...
# 7Progress: [ 27%] [###############...........................................] 8Selecting previously unselected package libxcb-render0-dev:amd64.
# Preparing to unpack .../21-libxcb-render0-dev_1.13-2~ubuntu18.04_amd64.deb ...
# Unpacking libxcb-render0-dev:amd64 (1.13-2~ubuntu18.04) ...
# 7Progress: [ 28%] [################..........................................] 8Selecting previously unselected package libxcb-randr0-dev:amd64.
# Preparing to unpack .../22-libxcb-randr0-dev_1.13-2~ubuntu18.04_amd64.deb ...
# 7Progress: [ 29%] [################..........................................] 8Unpacking libxcb-randr0-dev:amd64 (1.13-2~ubuntu18.04) ...
# Selecting previously unselected package libxcb-shape0-dev:amd64.
# Preparing to unpack .../23-libxcb-shape0-dev_1.13-2~ubuntu18.04_amd64.deb ...
# 7Progress: [ 30%] [#################.........................................] 8Unpacking libxcb-shape0-dev:amd64 (1.13-2~ubuntu18.04) ...
# 7Progress: [ 31%] [##################........................................] 8Selecting previously unselected package libxcb-xfixes0-dev:amd64.
# Preparing to unpack .../24-libxcb-xfixes0-dev_1.13-2~ubuntu18.04_amd64.deb ...
# Unpacking libxcb-xfixes0-dev:amd64 (1.13-2~ubuntu18.04) ...
# 7Progress: [ 32%] [##################........................................] 8Selecting previously unselected package libxcb-sync-dev:amd64.
# Preparing to unpack .../25-libxcb-sync-dev_1.13-2~ubuntu18.04_amd64.deb ...
# Unpacking libxcb-sync-dev:amd64 (1.13-2~ubuntu18.04) ...
# 7Progress: [ 33%] [###################.......................................] 8Selecting previously unselected package libxcb-present-dev:amd64.
# Preparing to unpack .../26-libxcb-present-dev_1.13-2~ubuntu18.04_amd64.deb ...
# 7Progress: [ 34%] [###################.......................................] 8Unpacking libxcb-present-dev:amd64 (1.13-2~ubuntu18.04) ...
# 7Progress: [ 35%] [####################......................................] 8Selecting previously unselected package libxshmfence-dev:amd64.
# Preparing to unpack .../27-libxshmfence-dev_1.3-1_amd64.deb ...
# Unpacking libxshmfence-dev:amd64 (1.3-1) ...
# 7Progress: [ 36%] [#####################.....................................] 8Selecting previously unselected package libxcb-dri2-0-dev:amd64.
# Preparing to unpack .../28-libxcb-dri2-0-dev_1.13-2~ubuntu18.04_amd64.deb ...
# Unpacking libxcb-dri2-0-dev:amd64 (1.13-2~ubuntu18.04) ...
# 7Progress: [ 37%] [#####################.....................................] 8Selecting previously unselected package libxcb-glx0-dev:amd64.
# Preparing to unpack .../29-libxcb-glx0-dev_1.13-2~ubuntu18.04_amd64.deb ...
# 7Progress: [ 38%] [######################....................................] 8Unpacking libxcb-glx0-dev:amd64 (1.13-2~ubuntu18.04) ...
# Selecting previously unselected package x11proto-fixes-dev.
# Preparing to unpack .../30-x11proto-fixes-dev_1%3a2018.4-4_all.deb ...
# 7Progress: [ 39%] [######################....................................] 8Unpacking x11proto-fixes-dev (1:2018.4-4) ...
# 7Progress: [ 40%] [#######################...................................] 8Selecting previously unselected package libxfixes-dev:amd64.
# Preparing to unpack .../31-libxfixes-dev_1%3a5.0.3-1_amd64.deb ...
# Unpacking libxfixes-dev:amd64 (1:5.0.3-1) ...
# 7Progress: [ 41%] [#######################...................................] 8Selecting previously unselected package x11proto-damage-dev.
# Preparing to unpack .../32-x11proto-damage-dev_1%3a2018.4-4_all.deb ...
# Unpacking x11proto-damage-dev (1:2018.4-4) ...
# 7Progress: [ 42%] [########################..................................] 8Selecting previously unselected package libxdamage-dev:amd64.
# Preparing to unpack .../33-libxdamage-dev_1%3a1.1.4-3_amd64.deb ...
# 7Progress: [ 43%] [#########################.................................] 8Unpacking libxdamage-dev:amd64 (1:1.1.4-3) ...
# 7Progress: [ 44%] [#########################.................................] 8Selecting previously unselected package x11proto-xext-dev.
# Preparing to unpack .../34-x11proto-xext-dev_2018.4-4_all.deb ...
# Unpacking x11proto-xext-dev (2018.4-4) ...
# 7Progress: [ 45%] [##########################................................] 8Selecting previously unselected package libxext-dev:amd64.
# Preparing to unpack .../35-libxext-dev_2%3a1.3.3-1_amd64.deb ...
# Unpacking libxext-dev:amd64 (2:1.3.3-1) ...
# 7Progress: [ 46%] [##########################................................] 8Selecting previously unselected package x11proto-xf86vidmode-dev.
# Preparing to unpack .../36-x11proto-xf86vidmode-dev_2018.4-4_all.deb ...
# 7Progress: [ 47%] [###########################...............................] 8Unpacking x11proto-xf86vidmode-dev (2018.4-4) ...
# 7Progress: [ 48%] [###########################...............................] 8Selecting previously unselected package libxxf86vm-dev:amd64.
# Preparing to unpack .../37-libxxf86vm-dev_1%3a1.1.4-1_amd64.deb ...
# Unpacking libxxf86vm-dev:amd64 (1:1.1.4-1) ...
# 7Progress: [ 49%] [############################..............................] 8Selecting previously unselected package libgl1-mesa-dev:amd64.
# Preparing to unpack .../38-libgl1-mesa-dev_20.0.8-0ubuntu1~18.04.1_amd64.deb ...
# Unpacking libgl1-mesa-dev:amd64 (20.0.8-0ubuntu1~18.04.1) ...
# 7Progress: [ 50%] [#############################.............................] 8Selecting previously unselected package libglu1-mesa-dev:amd64.
# Preparing to unpack .../39-libglu1-mesa-dev_9.0.0-2.1build1_amd64.deb ...
# 7Progress: [ 51%] [#############################.............................] 8Unpacking libglu1-mesa-dev:amd64 (9.0.0-2.1build1) ...
# Selecting previously unselected package libxt6:amd64.
# Preparing to unpack .../40-libxt6_1%3a1.1.5-1_amd64.deb ...
# 7Progress: [ 52%] [##############################............................] 8Unpacking libxt6:amd64 (1:1.1.5-1) ...
# 7Progress: [ 53%] [##############################............................] 8Selecting previously unselected package libice-dev:amd64.
# Preparing to unpack .../41-libice-dev_2%3a1.0.9-2_amd64.deb ...
# Unpacking libice-dev:amd64 (2:1.0.9-2) ...
# 7Progress: [ 54%] [###############################...........................] 8Selecting previously unselected package libsm-dev:amd64.
# Preparing to unpack .../42-libsm-dev_2%3a1.2.2-1_amd64.deb ...
# Unpacking libsm-dev:amd64 (2:1.2.2-1) ...
# 7Progress: [ 55%] [################################..........................] 8Selecting previously unselected package libxt-dev:amd64.
# Preparing to unpack .../43-libxt-dev_1%3a1.1.5-1_amd64.deb ...
# 7Progress: [ 56%] [################################..........................] 8Unpacking libxt-dev:amd64 (1:1.1.5-1) ...
# 7Progress: [ 57%] [#################################.........................] 8Selecting previously unselected package freeglut3-dev:amd64.
# Preparing to unpack .../44-freeglut3-dev_2.8.1-3_amd64.deb ...
# Unpacking freeglut3-dev:amd64 (2.8.1-3) ...
# 7Progress: [ 58%] [#################################.........................] 8Selecting previously unselected package libx11-doc.
# Preparing to unpack .../45-libx11-doc_2%3a1.6.4-3ubuntu0.3_all.deb ...
# Unpacking libx11-doc (2:1.6.4-3ubuntu0.3) ...
# 7Progress: [ 59%] [##################################........................] 8Setting up libopengl0:amd64 (1.0.0-2ubuntu2.3) ...
# 7Progress: [ 60%] [##################################........................] 8Setting up libgles1:amd64 (1.0.0-2ubuntu2.3) ...
# 7Progress: [ 61%] [###################################.......................] 8Setting up libxcb-randr0:amd64 (1.13-2~ubuntu18.04) ...
# 7Progress: [ 62%] [####################################......................] 8Setting up libxshmfence-dev:amd64 (1.3-1) ...
# 7Progress: [ 63%] [####################################......................] 8Setting up libpthread-stubs0-dev:amd64 (0.3-4) ...
# 7Progress: [ 64%] [#####################################.....................] 8Setting up libdrm-dev:amd64 (2.4.101-2~18.04.1) ...
# Setting up xorg-sgml-doctools (1:1.11-1) ...
# 7Progress: [ 65%] [#####################################.....................] 8Setting up x11proto-dev (2018.4-4) ...
# 7Progress: [ 66%] [######################################....................] 8Setting up x11proto-damage-dev (1:2018.4-4) ...
# 7Progress: [ 67%] [######################################....................] 8Setting up xtrans-dev (1.3.5-1) ...
# 7Progress: [ 68%] [#######################################...................] 8Setting up x11proto-xext-dev (2018.4-4) ...
# 7Progress: [ 69%] [########################################..................] 8Setting up libxdmcp-dev:amd64 (1:1.1.2-3) ...
# 7Progress: [ 70%] [########################################..................] 8Setting up libice6:amd64 (2:1.0.9-2) ...
# Setting up libx11-doc (2:1.6.4-3ubuntu0.3) ...
# 7Progress: [ 71%] [#########################################.................] 8Setting up libgles2:amd64 (1.0.0-2ubuntu2.3) ...
# 7Progress: [ 72%] [#########################################.................] 8Setting up libglvnd-core-dev:amd64 (1.0.0-2ubuntu2.3) ...
# 7Progress: [ 73%] [##########################################................] 8Setting up libsm6:amd64 (2:1.2.2-1) ...
# 7Progress: [ 74%] [##########################################................] 8Setting up x11proto-core-dev (2018.4-4) ...
# 7Progress: [ 75%] [###########################################...............] 8Setting up x11proto-fixes-dev (1:2018.4-4) ...
# 7Progress: [ 76%] [############################################..............] 8Setting up x11proto-xf86vidmode-dev (2018.4-4) ...
# 7Progress: [ 77%] [############################################..............] 8Setting up libxau-dev:amd64 (1:1.0.8-1ubuntu1) ...
# Setting up libglvnd-dev:amd64 (1.0.0-2ubuntu2.3) ...
# 7Progress: [ 78%] [#############################################.............] 8Setting up libice-dev:amd64 (2:1.0.9-2) ...
# 7Progress: [ 79%] [#############################################.............] 8Setting up libxt6:amd64 (1:1.1.5-1) ...
# 7Progress: [ 80%] [##############################################............] 8Setting up libxcb1-dev:amd64 (1.13-2~ubuntu18.04) ...
# 7Progress: [ 81%] [###############################################...........] 8Setting up libxcb-glx0-dev:amd64 (1.13-2~ubuntu18.04) ...
# 7Progress: [ 82%] [###############################################...........] 8Setting up libx11-dev:amd64 (2:1.6.4-3ubuntu0.3) ...
# 7Progress: [ 83%] [################################################..........] 8Setting up libxxf86vm-dev:amd64 (1:1.1.4-1) ...
# Setting up libxfixes-dev:amd64 (1:5.0.3-1) ...
# 7Progress: [ 84%] [################################################..........] 8Setting up libxcb-sync-dev:amd64 (1.13-2~ubuntu18.04) ...
# 7Progress: [ 85%] [#################################################.........] 8Setting up libx11-xcb-dev:amd64 (2:1.6.4-3ubuntu0.3) ...
# 7Progress: [ 86%] [#################################################.........] 8Setting up libsm-dev:amd64 (2:1.2.2-1) ...
# 7Progress: [ 87%] [##################################################........] 8Setting up mesa-common-dev:amd64 (20.0.8-0ubuntu1~18.04.1) ...
# 7Progress: [ 88%] [###################################################.......] 8Setting up libxdamage-dev:amd64 (1:1.1.4-3) ...
# 7Progress: [ 89%] [###################################################.......] 8Setting up libxcb-dri2-0-dev:amd64 (1.13-2~ubuntu18.04) ...
# 7Progress: [ 90%] [####################################################......] 8Setting up libxcb-render0-dev:amd64 (1.13-2~ubuntu18.04) ...
# Setting up libxcb-dri3-dev:amd64 (1.13-2~ubuntu18.04) ...
# 7Progress: [ 91%] [####################################################......] 8Setting up libxext-dev:amd64 (2:1.3.3-1) ...
# 7Progress: [ 92%] [#####################################################.....] 8Setting up libxcb-shape0-dev:amd64 (1.13-2~ubuntu18.04) ...
# 7Progress: [ 93%] [#####################################################.....] 8Setting up libxcb-randr0-dev:amd64 (1.13-2~ubuntu18.04) ...
# 7Progress: [ 94%] [######################################################....] 8Setting up libxt-dev:amd64 (1:1.1.5-1) ...
# 7Progress: [ 95%] [#######################################################...] 8Setting up libxcb-xfixes0-dev:amd64 (1.13-2~ubuntu18.04) ...
# 7Progress: [ 96%] [#######################################################...] 8Setting up libxcb-present-dev:amd64 (1.13-2~ubuntu18.04) ...
# Setting up libgl1-mesa-dev:amd64 (20.0.8-0ubuntu1~18.04.1) ...
# 7Progress: [ 97%] [########################################################..] 8Setting up libglu1-mesa-dev:amd64 (9.0.0-2.1build1) ...
# 7Progress: [ 98%] [########################################################..] 8Setting up freeglut3-dev:amd64 (2.8.1-3) ...
# 7Progress: [ 99%] [#########################################################.] 8Processing triggers for libc-bin (2.27-3ubuntu1) ...
#
# 78

# %%
import gym
import math
import random
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from collections import namedtuple
from itertools import count
from PIL import Image

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import torchvision.transforms as T


env = gym.make('CartPole-v0').unwrapped

# set up matplotlib
is_ipython = 'inline' in matplotlib.get_backend()
if is_ipython:
    from IPython import display

plt.ion()

# if gpu is to be used
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
Transition = namedtuple('Transition',
                        ('state', 'action', 'next_state', 'reward'))


class ReplayMemory(object):

    def __init__(self, capacity):
        self.capacity = capacity
        self.memory = []
        self.position = 0

    def push(self, *args):
        """Saves a transition."""
        if len(self.memory) < self.capacity:
            self.memory.append(None)
        self.memory[self.position] = Transition(*args)
        self.position = (self.position + 1) % self.capacity

    def sample(self, batch_size):
        return random.sample(self.memory, batch_size)

    def __len__(self):
        return len(self.memory)

# %%
class DQN(nn.Module):

    def __init__(self, h, w, outputs):
        super(DQN, self).__init__()
        self.conv1 = nn.Conv2d(3, 16, kernel_size=5, stride=2)
        self.bn1 = nn.BatchNorm2d(16)
        self.conv2 = nn.Conv2d(16, 32, kernel_size=5, stride=2)
        self.bn2 = nn.BatchNorm2d(32)
        self.conv3 = nn.Conv2d(32, 32, kernel_size=5, stride=2)
        self.bn3 = nn.BatchNorm2d(32)

        # Number of Linear input connections depends on output of conv2d layers
        # and therefore the input image size, so compute it.
        def conv2d_size_out(size, kernel_size = 5, stride = 2):
            return (size - (kernel_size - 1) - 1) // stride  + 1
        
        convw = conv2d_size_out(conv2d_size_out(conv2d_size_out(w)))
        convh = conv2d_size_out(conv2d_size_out(conv2d_size_out(h)))
        
        linear_input_size = convw * convh * 32
        
        self.head = nn.Linear(linear_input_size, outputs)

    # Called with either one element to determine next action, or a batch
    # during optimization. Returns tensor([[left0exp,right0exp]...]).
    def forward(self, x):
        x = F.relu(self.bn1(self.conv1(x)))
        x = F.relu(self.bn2(self.conv2(x)))
        x = F.relu(self.bn3(self.conv3(x)))
        return self.head(x.view(x.size(0), -1))

# %%
resize = T.Compose([T.ToPILImage(),
                    T.Resize(40, interpolation=Image.CUBIC),
                    T.ToTensor()])


def get_cart_location(screen_width):
    world_width = env.x_threshold * 2
    scale = screen_width / world_width
    return int(env.state[0] * scale + screen_width / 2.0)  # MIDDLE OF CART

def get_screen():
    # Returned screen requested by gym is 400x600x3, but is sometimes larger
    # such as 800x1200x3. Transpose it into torch order (CHW).
    screen = env.render(mode='rgb_array').transpose((2, 0, 1))
    # Cart is in the lower half, so strip off the top and bottom of the screen
    _, screen_height, screen_width = screen.shape
    screen = screen[:, int(screen_height*0.4):int(screen_height * 0.8)]
    view_width = int(screen_width * 0.6)
    cart_location = get_cart_location(screen_width)
    if cart_location < view_width // 2:
        slice_range = slice(view_width)
    elif cart_location > (screen_width - view_width // 2):
        slice_range = slice(-view_width, None)
    else:
        slice_range = slice(cart_location - view_width // 2,
                            cart_location + view_width // 2)
    # Strip off the edges, so that we have a square image centered on a cart
    screen = screen[:, :, slice_range]
    # Convert to float, rescale, convert to torch tensor
    # (this doesn't require a copy)
    screen = np.ascontiguousarray(screen, dtype=np.float32) / 255
    screen = torch.from_numpy(screen)
    # Resize, and add a batch dimension (BCHW)
    return resize(screen).unsqueeze(0).to(device)

env.reset()
plt.figure()
plt.imshow(get_screen().cpu().squeeze(0).permute(1, 2, 0).numpy(),
           interpolation='none')
plt.title('Example extracted screen')
plt.show()

# %%
BATCH_SIZE = 128
GAMMA = 0.999
EPS_START = 0.9
EPS_END = 0.05
EPS_DECAY = 200
TARGET_UPDATE = 10

# Get screen size so that we can initialize layers correctly based on shape
# returned from AI gym. Typical dimensions at this point are close to 3x40x90
# which is the result of a clamped and down-scaled render buffer in get_screen()
init_screen = get_screen()
_, _, screen_height, screen_width = init_screen.shape

# Get number of actions from gym action space
n_actions = env.action_space.n

policy_net = DQN(screen_height, screen_width, n_actions).to(device)
target_net = DQN(screen_height, screen_width, n_actions).to(device)
target_net.load_state_dict(policy_net.state_dict())
target_net.eval()

optimizer = optim.RMSprop(policy_net.parameters())
memory = ReplayMemory(10000)


steps_done = 0


def select_action(state):
    global steps_done
    sample = random.random()
    eps_threshold = EPS_END + (EPS_START - EPS_END) * \
        math.exp(-1. * steps_done / EPS_DECAY)
    steps_done += 1
    if sample > eps_threshold:
        with torch.no_grad():
            # t.max(1) will return largest column value of each row.
            # second column on max result is index of where max element was
            # found, so we pick action with the larger expected reward.
            return policy_net(state).max(1)[1].view(1, 1)
    else:
        return torch.tensor([[random.randrange(n_actions)]], device=device, dtype=torch.long)


episode_durations = []


def plot_durations():
    plt.figure(2)
    plt.clf()
    durations_t = torch.tensor(episode_durations, dtype=torch.float)
    plt.title('Training...')
    plt.xlabel('Episode')
    plt.ylabel('Duration')
    plt.plot(durations_t.numpy())
    # Take 100 episode averages and plot them too
    if len(durations_t) >= 100:
        means = durations_t.unfold(0, 100, 1).mean(1).view(-1)
        means = torch.cat((torch.zeros(99), means))
        plt.plot(means.numpy())

    plt.pause(0.001)  # pause a bit so that plots are updated
    if is_ipython:
        display.clear_output(wait=True)
        display.display(plt.gcf())

# %%
def optimize_model():
    if len(memory) < BATCH_SIZE:
        return
    transitions = memory.sample(BATCH_SIZE)
    # Transpose the batch (see https://stackoverflow.com/a/19343/3343043 for
    # detailed explanation). This converts batch-array of Transitions
    # to Transition of batch-arrays.
    batch = Transition(*zip(*transitions))

    # Compute a mask of non-final states and concatenate the batch elements
    # (a final state would've been the one after which simulation ended)
    non_final_mask = torch.tensor(tuple(map(lambda s: s is not None,
                                          batch.next_state)), device=device, dtype=torch.bool)
    
    non_final_next_states = torch.cat([s for s in batch.next_state
                                                if s is not None])
    state_batch = torch.cat(batch.state)
    action_batch = torch.cat(batch.action)
    reward_batch = torch.cat(batch.reward)

    # Compute Q(s_t, a) - the model computes Q(s_t), then we select the
    # columns of actions taken. These are the actions which would've been taken
    # for each batch state according to policy_net
    state_action_values = policy_net(state_batch).gather(1, action_batch)

    # Compute V(s_{t+1}) for all next states.
    # Expected values of actions for non_final_next_states are computed based
    # on the "older" target_net; selecting their best reward with max(1)[0].
    # This is merged based on the mask, such that we'll have either the expected
    # state value or 0 in case the state was final.
    next_state_values = torch.zeros(BATCH_SIZE, device=device)
    next_state_values[non_final_mask] = target_net(non_final_next_states).max(1)[0].detach()
    # Compute the expected Q values
    expected_state_action_values = (next_state_values * GAMMA) + reward_batch

    # Compute Huber loss
    loss = F.smooth_l1_loss(state_action_values, expected_state_action_values.unsqueeze(1))

    # Optimize the model
    optimizer.zero_grad()
    loss.backward()
    for param in policy_net.parameters():
        param.grad.data.clamp_(-1, 1)
    optimizer.step()

# %%
num_episodes = 1200
for i_episode in range(num_episodes):
    # Initialize the environment and state
    env.reset()
    last_screen = get_screen()
    current_screen = get_screen()
    state = current_screen - last_screen
    for t in count():
        # Select and perform an action
        action = select_action(state)
        _, reward, done, _ = env.step(action.item())
        reward = torch.tensor([reward], device=device)

        # Observe new state
        last_screen = current_screen
        current_screen = get_screen()
        if not done:
            next_state = current_screen - last_screen
        else:
            next_state = None

        # Store the transition in memory
        memory.push(state, action, next_state, reward)

        # Move to the next state
        state = next_state

        # Perform one step of the optimization (on the target network)
        optimize_model()
        if done:
            episode_durations.append(t + 1)
            print('episode_durations =', t + 1)
            plot_durations()
            break
    # Update the target network, copying all weights and biases in DQN
    if i_episode % TARGET_UPDATE == 0:
        target_net.load_state_dict(policy_net.state_dict())

print('Complete')
env.render()
env.close()
plt.ioff()
plt.show()
# Out:
# Complete

# %%
env.close()
plt.ioff()
plt.show()
